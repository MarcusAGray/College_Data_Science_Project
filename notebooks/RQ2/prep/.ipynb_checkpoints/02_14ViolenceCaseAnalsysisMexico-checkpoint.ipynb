# %%
"""
Basic processing for uk data sets
Loads;  

america.csv
brazil.csv

Produces;
df.csv
"""
# Out:
# '\nBasic processing for uk data sets\nLoads;  \n\namerica.csv\nbrazil.csv\n\nProduces;\ndf.csv\n'

# %% [markdown]
# # Setup

# %% [markdown]
# ## Imports

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# ## Parameters

# %% [markdown]
# Configuration

# %% [markdown]
# ### Loading the datasets

# %%
df = pd.read_csv("../../data/processed/df.csv")

# %%
df = df[df['country'].str.fullmatch('Mexico')]

# %%
df.head()
# Out:
#        country measure   location     sex  age_sort       age  \
# 392160  Mexico  Deaths  Nicaragua    Male         0    1 to 4
# 392161  Mexico  Deaths  Nicaragua  Female         0    1 to 4
# 392162  Mexico  Deaths  Nicaragua    Male         1    5 to 9
# 392163  Mexico  Deaths  Nicaragua  Female         1    5 to 9
# 392164  Mexico  Deaths  Nicaragua    Male         2  10 to 14
#
#                          cause  year       val
# 392160  Interpersonal violence  2010  1.628516
# 392161  Interpersonal violence  2010  1.734527
# 392162  Interpersonal violence  2010  1.079049
# 392163  Interpersonal violence  2010  0.725533
# 392164  Interpersonal violence  2010  2.707576

# %%
df.shape
# Out:
# (53200, 9)

# %%
#look for demographs with the highest rates of violence - is the harm from violence greater than overall diabetes avg? 2)the harm from diabetes of that region and 2) higher than the harm nationwide?
#Which of these demographs have a high consistency (across time and country)?

#How many groups are there proportionally that should be more concerned of violent crime than diabetes?

# %% [markdown]
# ### Calculate overall diabetes average

# %%
overall_diabetes_death_avg = df[df['measure'].str.contains('Deaths') &
                 df['cause'].str.contains('Diabetes')]
overall_diabetes_death_avg = overall_diabetes_death_avg['val'].mean()
overall_diabetes_death_avg
# Out:
# 219.03242388793834

# %% [markdown]
# ### Create table of demographs with homicide rate higher than diabetes average

# %%
#get rows with higher homicide rate than overall_diabetes_avg
high_violence_death_rate_demos = df[df['measure'].str.contains('Deaths') &
                  df['cause'].str.contains('Interpersonal violence')]

high_violence_death_rate_demos = high_violence_death_rate_demos[high_violence_death_rate_demos['val'] > overall_diabetes_death_avg]
high_violence_death_rate_demos = high_violence_death_rate_demos.sort_values(by=['val'], ascending=False)
high_violence_death_rate_demos.shape
# Out:
# (18, 9)

# %%
high_violence_death_rate_demos.head()
# Out:
#        country measure   location   sex  age_sort       age  \
# 393122  Mexico  Deaths  Chihuahua  Male         2  30 to 34
# 415821  Mexico  Deaths     Colima  Male         2  30 to 34
# 393120  Mexico  Deaths  Chihuahua  Male         2  25 to 29
# 396782  Mexico  Deaths  Chihuahua  Male         2  30 to 34
# 393124  Mexico  Deaths  Chihuahua  Male         2  35 to 39
#
#                          cause  year         val
# 393122  Interpersonal violence  2010  272.993521
# 415821  Interpersonal violence  2017  254.606348
# 393120  Interpersonal violence  2010  253.549958
# 396782  Interpersonal violence  2011  245.731294
# 393124  Interpersonal violence  2010  244.790055

# %% [markdown]
# ## Death Rate exploration

# %%
gender = high_violence_death_rate_demos.groupby(['sex'], as_index=False).agg({'val':'mean'})

# %%
gender.plot(x="sex", y="val", kind="bar")
plt.show()

# %%
age = high_violence_death_rate_demos.groupby(['age'], as_index=False).agg({'val':'mean'})

# %%
age.plot(x="age", y="val", kind="bar")
plt.show()

# %%
#location what proportions of the regions have been consistent through time
#We can look at locations that have held within them one demograph that has a higher homicide rate than diabetes death rate
#And we can examine how consistent across time these region have sustained such a demograph

# %%
locations_containing_high_violence_demos = high_violence_death_rate_demos.groupby(['location', 'year'], as_index=False).agg({'year': 'count', 'val':'mean'})
locations_containing_high_violence_demos.head(20)
# Out:
#                              location  year         val
# 0                           Chihuahua     3  257.111178
# 1                           Chihuahua     3  239.451545
# 2                              Colima     4  243.057819
# 3                              Colima     3  224.962579
# 4                              Colima     2  223.276924
# 5                            Guerrero     1  222.777884
# 6  Venezuela (Bolivarian Republic of)     1  221.556624
# 7  Venezuela (Bolivarian Republic of)     1  224.615374

# %%
location_by_year_frequency = locations_containing_high_violence_demos.groupby('location').count()
location_by_year_frequency['val'].describe()
# Out:
# count    4.000000
# mean     2.000000
# std      0.816497
# min      1.000000
# 25%      1.750000
# 50%      2.000000
# 75%      2.250000
# max      3.000000
# Name: val, dtype: float64

# %%
location_by_year_frequency
# Out:
#                                     year  val
# location
# Chihuahua                              2    2
# Colima                                 3    3
# Guerrero                               1    1
# Venezuela (Bolivarian Republic of)     2    2

# %%
#Try to find out by homw much frequency of demos with homicide rate higher than ddiabetes agerage
#location_demo_frequency = locations_containing_high_violence_demos.groupby('location').agg('year':'mean')# or try to measure distribution
#location_by_year_frequency['val'].describe()

# %%
country_filter = high_violence_death_rate_demos.groupby('country').count()['val']
country_filter
#So the uk and japan don't have any internal region with crime rateo over diabetes average
# Out:
# country
# Mexico    18
# Name: val, dtype: int64

# %%
location_filter = high_violence_death_rate_demos.groupby('location', as_index=False).count()
location_filter = location_filter[['location', 'val']]
location_filter
# Out:
#                              location  val
# 0                           Chihuahua    6
# 1                              Colima    9
# 2                            Guerrero    1
# 3  Venezuela (Bolivarian Republic of)    2

# %%
gender_filter = high_violence_death_rate_demos.groupby('sex', as_index=False).count()
gender_filter
# Out:
#     sex  country  measure  location  age_sort  age  cause  year  val
# 0  Male       18       18        18        18   18     18    18   18

# %%
age_filter = high_violence_death_rate_demos.groupby('age', as_index=False).count()
age_filter = age_filter[['age', 'val']]
age_filter
# Out:
#         age  val
# 0  20 to 24    2
# 1  25 to 29    3
# 2  30 to 34    4
# 3  35 to 39    5
# 4  40 to 44    3
# 5  50 to 54    1

# %%
#we campare number of demographs (using deaths) vs the total number of demographs that have a higher iv homicide rate than 
#overall overall average.
newdf = df[df['measure'].str.contains("Deaths")]
print("Total number of sub groups: ", len(newdf))
print("Number of sub groups with higher violence death rate than diabetes death rate: ", len(high_violence_death_rate_demos))
# Out:
# Total number of sub groups:  26600
# Number of sub groups with higher violence death rate than diabetes death rate:  18

# %% [markdown]
# ### Create table that lets us compare high homicde demographs to their corresponding diabetes death rates

# %%
diabetes_death = df[df['measure'].str.contains('Deaths') &
             df['cause'].str.contains('Diabetes')]

# %%
#https://stackoverflow.com/questions/54006298/select-rows-of-a-dataframe-based-on-another-dataframe-in-python

#create a new df using multiindex to combine the high homicide demographs with their corresponding diabetes deaths
#This cell get the diabetes rows
diabetes_death = diabetes_death[diabetes_death.set_index(['country','location', 'sex', 'age', 'year']).index.isin(high_violence_death_rate_demos.set_index(['country', 'location', 'sex', 'age', 'year']).index)]
newdf.shape
# Out:
# (26600, 9)

# %%
#combine the tables 
higher_violence_death_rate_with_diabetes = diabetes_death.append(high_violence_death_rate_demos)
higher_violence_death_rate_with_diabetes = higher_violence_death_rate_with_diabetes.sort_values(by=['location', 'sex', 'age', 'year'])
higher_violence_death_rate_with_diabetes.head(40)
# Out:
#        country measure                            location   sex  age_sort  \
# 393360  Mexico  Deaths                           Chihuahua  Male         2
# 393120  Mexico  Deaths                           Chihuahua  Male         2
# 402206  Mexico  Deaths                           Chihuahua  Male         2
# 396780  Mexico  Deaths                           Chihuahua  Male         2
# 393362  Mexico  Deaths                           Chihuahua  Male         2
# 393122  Mexico  Deaths                           Chihuahua  Male         2
# 402208  Mexico  Deaths                           Chihuahua  Male         2
# 396782  Mexico  Deaths                           Chihuahua  Male         2
# 393364  Mexico  Deaths                           Chihuahua  Male         2
# 393124  Mexico  Deaths                           Chihuahua  Male         2
# 402210  Mexico  Deaths                           Chihuahua  Male         2
# 396784  Mexico  Deaths                           Chihuahua  Male         2
# 415781  Mexico  Deaths                              Colima  Male         2
# 415819  Mexico  Deaths                              Colima  Male         2
# 415783  Mexico  Deaths                              Colima  Male         2
# 415821  Mexico  Deaths                              Colima  Male         2
# 442093  Mexico  Deaths                              Colima  Male         2
# 442131  Mexico  Deaths                              Colima  Male         2
# 415785  Mexico  Deaths                              Colima  Male         2
# 415823  Mexico  Deaths                              Colima  Male         2
# 442095  Mexico  Deaths                              Colima  Male         2
# 442133  Mexico  Deaths                              Colima  Male         2
# 421710  Mexico  Deaths                              Colima  Male         2
# 421748  Mexico  Deaths                              Colima  Male         2
# 415787  Mexico  Deaths                              Colima  Male         2
# 415825  Mexico  Deaths                              Colima  Male         2
# 442097  Mexico  Deaths                              Colima  Male         2
# 442135  Mexico  Deaths                              Colima  Male         2
# 421712  Mexico  Deaths                              Colima  Male         2
# 421750  Mexico  Deaths                              Colima  Male         2
# 401764  Mexico  Deaths                            Guerrero  Male         2
# 409432  Mexico  Deaths                            Guerrero  Male         2
# 395768  Mexico  Deaths  Venezuela (Bolivarian Republic of)  Male         2
# 395806  Mexico  Deaths  Venezuela (Bolivarian Republic of)  Male         2
# 397268  Mexico  Deaths  Venezuela (Bolivarian Republic of)  Male         2
# 397306  Mexico  Deaths  Venezuela (Bolivarian Republic of)  Male         2
#
#              age                   cause  year         val
# 393360  25 to 29       Diabetes mellitus  2010    2.381669
# 393120  25 to 29  Interpersonal violence  2010  253.549958
# 402206  25 to 29       Diabetes mellitus  2011    2.358156
# 396780  25 to 29  Interpersonal violence  2011  240.726064
# 393362  30 to 34       Diabetes mellitus  2010    4.648314
# 393122  30 to 34  Interpersonal violence  2010  272.993521
# 402208  30 to 34       Diabetes mellitus  2011    4.410838
# 396782  30 to 34  Interpersonal violence  2011  245.731294
# 393364  35 to 39       Diabetes mellitus  2010    8.678222
# 393124  35 to 39  Interpersonal violence  2010  244.790055
# 402210  35 to 39       Diabetes mellitus  2011    8.346884
# 396784  35 to 39  Interpersonal violence  2011  231.897276
# 415781  25 to 29       Diabetes mellitus  2017    4.757037
# 415819  25 to 29  Interpersonal violence  2017  242.612525
# 415783  30 to 34       Diabetes mellitus  2017    9.171997
# 415821  30 to 34  Interpersonal violence  2017  254.606348
# 442093  30 to 34       Diabetes mellitus  2018    8.575223
# 442131  30 to 34  Interpersonal violence  2018  226.908834
# 415785  35 to 39       Diabetes mellitus  2017   13.632259
# 415823  35 to 39  Interpersonal violence  2017  241.416232
# 442095  35 to 39       Diabetes mellitus  2018   13.731570
# 442133  35 to 39  Interpersonal violence  2018  225.477162
# 421710  35 to 39       Diabetes mellitus  2019   13.516101
# 421748  35 to 39  Interpersonal violence  2019  223.186146
# 415787  40 to 44       Diabetes mellitus  2017   29.816414
# 415825  40 to 44  Interpersonal violence  2017  233.596171
# 442097  40 to 44       Diabetes mellitus  2018   30.281051
# 442135  40 to 44  Interpersonal violence  2018  222.501742
# 421712  40 to 44       Diabetes mellitus  2019   29.775725
# 421750  40 to 44  Interpersonal violence  2019  223.367701
# 401764  50 to 54       Diabetes mellitus  2011  104.300988
# 409432  50 to 54  Interpersonal violence  2011  222.777884
# 395768  20 to 24       Diabetes mellitus  2012    0.889161
# 395806  20 to 24  Interpersonal violence  2012  221.556624
# 397268  20 to 24       Diabetes mellitus  2013    0.847055
# 397306  20 to 24  Interpersonal violence  2013  224.615374

# %%
higher_violence_death_rate_with_diabetes.shape
# Out:
# (36, 9)

# %% [markdown]
# ## YLL rate Exploration

# %% [markdown]
# ### Calculate overall diabetes average for YLLs

# %%
overall_diabetes_yll_avg = df[df['measure'].str.contains('YLL') &
                 df['cause'].str.contains('Diabetes')]
overall_diabetes_yll_avg = overall_diabetes_yll_avg['val'].mean()
overall_diabetes_yll_avg
# Out:
# 2998.356410080414

# %% [markdown]
# ### Create table of demographs with higher homicide rate

# %%
#get rows with higher homicide rate than overall_diabetes_avg
high_violence_yll_demos = df[df['measure'].str.contains('YLL') &
                  df['cause'].str.contains('Interpersonal violence')]

high_violence_yll_demos = high_violence_yll_demos[high_violence_yll_demos['val'] > overall_diabetes_yll_avg]
high_violence_yll_demos = high_violence_yll_demos.sort_values(by=['val'], ascending=False)
high_violence_yll_demos.shape
# Out:
# (1177, 9)

# %% [markdown]
# ## YLL Rate exploration

# %%
gender = high_violence_yll_demos.groupby(['sex'], as_index=False).agg({'val':'mean'})

# %%
gender.plot(x="sex", y="val", kind="bar")
plt.show()

# %%
age = high_violence_yll_demos.groupby(['age'], as_index=False).agg({'val':'mean'})

# %%
age.plot(x="age", y="val", kind="bar")
plt.show()

# %%
#location what proportions of the regions have been consistent through time
#We can look at locations that have held within them one demograph that has a higher homicide rate than diabetes death rate
#And we can examine how consistent across time these region have sustained such a demograph

# %%
locations_containing_high_violence_demos = high_violence_yll_demos.groupby(['location', 'year'], as_index=False).agg({'year': 'count', 'val':'mean'})
locations_containing_high_violence_demos.head(20)
#38 demos in each region (for one year)
# Out:
#                location  year           val
# 0       Baja California     6   5582.085930
# 1       Baja California     5   4499.027310
# 2       Baja California     5   3855.057843
# 3       Baja California     5   4295.116741
# 4       Baja California     5   4396.848374
# 5       Baja California     6   4630.829301
# 6       Baja California     6   5682.429716
# 7       Baja California     7   6622.072107
# 8       Baja California     9   6552.189362
# 9       Baja California     9   6345.694514
# 10  Baja California Sur     4   3641.722860
# 11  Baja California Sur     4   5129.738002
# 12  Baja California Sur     7   5961.130102
# 13  Baja California Sur     6   5163.434228
# 14  Baja California Sur     4   4638.459157
# 15              Chiapas     1   3010.403104
# 16              Chiapas     3   3497.305805
# 17              Chiapas     2   3303.536745
# 18            Chihuahua     9  10289.070348
# 19            Chihuahua     9   9582.079315

# %%
location_by_year_frequency = locations_containing_high_violence_demos.groupby('location').count()
location_by_year_frequency['val'].describe()
#We can see average is 7 - so locations sustaining over diabetes average deaths rates likely to keep doing so
# Out:
# count    28.000000
# mean      8.250000
# std       2.503701
# min       3.000000
# 25%       6.000000
# 50%      10.000000
# 75%      10.000000
# max      10.000000
# Name: val, dtype: float64

# %%
location_by_year_frequency
# Out:
#                                     year  val
# location
# Baja California                       10   10
# Baja California Sur                    5    5
# Chiapas                                3    3
# Chihuahua                             10   10
# Coahuila                               5    5
# Colima                                10   10
# Durango                               10   10
# Guanajuato                             7    7
# Guerrero                              10   10
# Jalisco                               10   10
# Mexico City                            8    8
# Michoacán de Ocampo                   10   10
# Morelos                               10   10
# México                                10   10
# Nayarit                               10   10
# Nuevo León                             6    6
# Oaxaca                                10   10
# Panama                                10   10
# Puebla                                 3    3
# Quintana Roo                           4    4
# San Luis Potosí                        6    6
# Sinaloa                               10   10
# Sonora                                10   10
# Tabasco                                5    5
# Tamaulipas                            10   10
# Venezuela (Bolivarian Republic of)    10   10
# Veracruz de Ignacio de la Llave        9    9
# Zacatecas                             10   10

# %% [markdown]
# ### Take high_violence_ylls_demos and filter on the consistent demographs

# %%
high_violence_yll_demos.groupby('country').count()['val']
# Out:
# country
# Mexico    1177
# Name: val, dtype: int64

# %%
location_filter = high_violence_yll_demos.groupby('location', as_index=False).count()
location_filter = location_filter[['location', 'val']]
location_filter
# Out:
#                               location  val
# 0                      Baja California   63
# 1                  Baja California Sur   25
# 2                              Chiapas    6
# 3                            Chihuahua   84
# 4                             Coahuila   13
# 5                               Colima   66
# 6                              Durango   47
# 7                           Guanajuato   35
# 8                             Guerrero  108
# 9                              Jalisco   40
# 10                         Mexico City   20
# 11                 Michoacán de Ocampo   58
# 12                             Morelos   61
# 13                              México   31
# 14                             Nayarit   43
# 15                          Nuevo León   15
# 16                              Oaxaca   52
# 17                              Panama   32
# 18                              Puebla    9
# 19                        Quintana Roo   22
# 20                     San Luis Potosí   14
# 21                             Sinaloa   74
# 22                              Sonora   47
# 23                             Tabasco   18
# 24                          Tamaulipas   50
# 25  Venezuela (Bolivarian Republic of)   64
# 26     Veracruz de Ignacio de la Llave   32
# 27                           Zacatecas   48

# %%
gender_filter = high_violence_yll_demos.groupby('sex', as_index=False).count()
gender_filter = gender_filter[['sex', 'val']]
gender_filter
# Out:
#     sex   val
# 0  Male  1177

# %%
age_filter = high_violence_yll_demos.groupby('age', as_index=False).count()
age_filter = age_filter[['age', 'val']]
age_filter
# Out:
#          age  val
# 0   15 to 19   82
# 1   20 to 24  224
# 2   25 to 29  226
# 3   30 to 34  206
# 4   35 to 39  171
# 5   40 to 44  126
# 6   45 to 49   69
# 7   50 to 54   36
# 8   55 to 59   19
# 9   60 to 64    9
# 10  65 to 69    8
# 11  70 to 74    1

# %%
#we campare number of demographs (using deaths) vs the total number of demographs that have a higher iv homicide rate than 
#overall overall average.
newdf = df[df['measure'].str.contains("YLL")]
print("Total number of sub groups: ", len(newdf))
print("Number of sub groups with higher violence death rate than diabetes death rate: ", len(high_violence_yll_demos))
# Out:
# Total number of sub groups:  26600
# Number of sub groups with higher violence death rate than diabetes death rate:  1177

# %% [markdown]
# ### Create table that lets us compare high homicde demographs to their corresponding diabetes yll rates

# %%
diabetes_ylls = df[df['measure'].str.contains('YLL') &
             df['cause'].str.contains('Diabetes')]

# %%
#https://stackoverflow.com/questions/54006298/select-rows-of-a-dataframe-based-on-another-dataframe-in-python

#create a new df using multiindex to combine the high homicide demographs with their corresponding diabetes deaths
#This cell get the diabetes rows
diabetes_ylls = diabetes_ylls[diabetes_ylls.set_index(['country','location', 'sex', 'age', 'year']).index.isin(high_violence_yll_demos.set_index(['country', 'location', 'sex', 'age', 'year']).index)]
diabetes_ylls.shape
# Out:
# (1177, 9)

# %%
#combine the tables 
higher_violence_ylls_with_diabetes = diabetes_ylls.append(high_violence_yll_demos)
higher_violence_ylls_with_diabetes = higher_violence_ylls_with_diabetes.sort_values(by=['location', 'sex', 'age', 'year'])
higher_violence_ylls_with_diabetes.head(20)
# Out:
#        country                    measure         location   sex  age_sort  \
# 431620  Mexico  YLLs (Years of Life Lost)  Baja California  Male         2
# 431658  Mexico  YLLs (Years of Life Lost)  Baja California  Male         2
# 433194  Mexico  YLLs (Years of Life Lost)  Baja California  Male         2
# 433270  Mexico  YLLs (Years of Life Lost)  Baja California  Male         2
# 395206  Mexico  YLLs (Years of Life Lost)  Baja California  Male         2
# 395244  Mexico  YLLs (Years of Life Lost)  Baja California  Male         2
# 399749  Mexico  YLLs (Years of Life Lost)  Baja California  Male         2
# 402778  Mexico  YLLs (Years of Life Lost)  Baja California  Male         2
# 402984  Mexico  YLLs (Years of Life Lost)  Baja California  Male         2
# 407084  Mexico  YLLs (Years of Life Lost)  Baja California  Male         2
# 403288  Mexico  YLLs (Years of Life Lost)  Baja California  Male         2
# 403326  Mexico  YLLs (Years of Life Lost)  Baja California  Male         2
# 418930  Mexico  YLLs (Years of Life Lost)  Baja California  Male         2
# 428240  Mexico  YLLs (Years of Life Lost)  Baja California  Male         2
# 420706  Mexico  YLLs (Years of Life Lost)  Baja California  Male         2
# 420744  Mexico  YLLs (Years of Life Lost)  Baja California  Male         2
# 435562  Mexico  YLLs (Years of Life Lost)  Baja California  Male         2
# 435600  Mexico  YLLs (Years of Life Lost)  Baja California  Male         2
# 421022  Mexico  YLLs (Years of Life Lost)  Baja California  Male         2
# 432550  Mexico  YLLs (Years of Life Lost)  Baja California  Male         2
#
#              age                   cause  year          val
# 431620  15 to 19       Diabetes mellitus  2018    33.881914
# 431658  15 to 19  Interpersonal violence  2018  3373.475959
# 433194  15 to 19       Diabetes mellitus  2019    32.204432
# 433270  15 to 19  Interpersonal violence  2019  3262.929497
# 395206  20 to 24       Diabetes mellitus  2010    89.947002
# 395244  20 to 24  Interpersonal violence  2010  5547.539563
# 399749  20 to 24       Diabetes mellitus  2011    84.993549
# 402778  20 to 24  Interpersonal violence  2011  4325.337074
# 402984  20 to 24       Diabetes mellitus  2012    80.435715
# 407084  20 to 24  Interpersonal violence  2012  3735.608582
# 403288  20 to 24       Diabetes mellitus  2013    86.811502
# 403326  20 to 24  Interpersonal violence  2013  4100.135131
# 418930  20 to 24       Diabetes mellitus  2014    84.020709
# 428240  20 to 24  Interpersonal violence  2014  3820.430379
# 420706  20 to 24       Diabetes mellitus  2015    86.768837
# 420744  20 to 24  Interpersonal violence  2015  4358.226379
# 435562  20 to 24       Diabetes mellitus  2016    99.321374
# 435600  20 to 24  Interpersonal violence  2016  5466.028508
# 421022  20 to 24       Diabetes mellitus  2017   103.858488
# 432550  20 to 24  Interpersonal violence  2017  6761.650236

# %%
higher_violence_ylls_with_diabetes.shape
# Out:
# (2354, 9)

# %%
#could show distribution of high homicide locations

# %%
#make observation of this data = doesn't seem like high crime rate is follow by high diabetes - so maybe not common cause like poor hospitals.

# %%
#Can perhaps remark on how geographical location seems very important - not just 'Brazil' but specific location in brazil

# %%
#Now should do the above for specific countries
