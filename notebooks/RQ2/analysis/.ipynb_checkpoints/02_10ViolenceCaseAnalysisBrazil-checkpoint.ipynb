# %% [markdown]
# # Violence Case Analysis for Brazil

# %% [markdown]
# # Setup

# %% [markdown]
# ## Imports

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import geopandas as gpd

# %% [markdown]
# ## Parameters

# %%
ALL_COUNTRIES_DATASET = "../../../data/RQ2/processed/all_countries_df.csv"
BRAZIL_MAP_DATA = "../../../data/RQ2/raw/bcim_2016_21_11_2018.gpkg"

# %% [markdown]
# ## Configuration

# %%
# %matplotlib inline

# %% [markdown]
# # Loading the Datasets

# %%
df = pd.read_csv(ALL_COUNTRIES_DATASET)

# %%
df = df[df['country'].str.fullmatch('Brazil')]

# %%
df.head()
# Out:
#        country                    measure location     sex  age_sort  \
# 456000  Brazil  YLLs (Years of Life Lost)   Paraná    Male         0
# 456001  Brazil  YLLs (Years of Life Lost)   Paraná  Female         0
# 456002  Brazil  YLLs (Years of Life Lost)   Paraná    Male         1
# 456003  Brazil  YLLs (Years of Life Lost)   Paraná  Female         1
# 456004  Brazil  YLLs (Years of Life Lost)   Paraná    Male         2
#
#              age                   cause  year         val
# 456000    1 to 4  Interpersonal violence  2010  145.114710
# 456001    1 to 4  Interpersonal violence  2010  109.739815
# 456002    5 to 9  Interpersonal violence  2010  141.150050
# 456003    5 to 9  Interpersonal violence  2010   87.885475
# 456004  10 to 14  Interpersonal violence  2010  654.965579

# %%
df.shape
# Out:
# (61560, 9)

# %% [markdown]
# ### Calculate overall diabetes average in Brazil only

# %%
overall_diabetes_death_avg = df[df['measure'].str.contains('Deaths') &
                 df['cause'].str.contains('Diabetes')]
overall_diabetes_death_avg = overall_diabetes_death_avg['val'].mean()
overall_diabetes_death_avg
# Out:
# 136.1865621273738

# %% [markdown]
# ### Create table of demographs with homicide rate higher than diabetes average

# %%
#get rows with higher homicide rate than overall_diabetes_avg
high_violence_death_rate_demos = df[df['measure'].str.contains('Deaths') &
                  df['cause'].str.contains('Interpersonal violence')]

high_violence_death_rate_demos = high_violence_death_rate_demos[high_violence_death_rate_demos['val'] > overall_diabetes_death_avg]
high_violence_death_rate_demos = high_violence_death_rate_demos.sort_values(by=['val'], ascending=False)
high_violence_death_rate_demos.shape
# Out:
# (407, 9)

# %%
high_violence_death_rate_demos.head()
# Out:
#        country measure location   sex  age_sort       age  \
# 457900  Brazil  Deaths  Alagoas  Male         2  20 to 24
# 456452  Brazil  Deaths  Alagoas  Male         2  20 to 24
# 460141  Brazil  Deaths  Alagoas  Male         2  20 to 24
# 459878  Brazil  Deaths  Alagoas  Male         2  20 to 24
# 469044  Brazil  Deaths  Alagoas  Male         2  20 to 24
#
#                          cause  year         val
# 457900  Interpersonal violence  2011  390.170354
# 456452  Interpersonal violence  2010  378.401649
# 460141  Interpersonal violence  2012  359.100583
# 459878  Interpersonal violence  2013  349.784489
# 469044  Interpersonal violence  2014  326.618712

# %% [markdown]
# ## Death Rate exploration

# %%
gender = high_violence_death_rate_demos.groupby(['sex'], as_index=False).agg({'val':'mean'})

gender.plot(x="sex", y="val", kind="bar")
plt.show()

# %%
age = high_violence_death_rate_demos.groupby(['age'], as_index=False).agg({'val':'mean'})

age.plot(x="age", y="val", kind="bar")
plt.show()

# %%
locations_containing_high_violence_demos = high_violence_death_rate_demos.groupby(['location', 'year'], as_index=False).agg({'year': 'count', 'val':'mean'})
locations_containing_high_violence_demos.head(20)
# Out:
#    location  year         val
# 0      Acre     2  144.680689
# 1      Acre     3  155.462412
# 2   Alagoas     6  240.058929
# 3   Alagoas     6  247.131925
# 4   Alagoas     6  231.210221
# 5   Alagoas     5  244.328924
# 6   Alagoas     6  217.312412
# 7   Alagoas     5  211.546078
# 8   Alagoas     5  208.679168
# 9   Alagoas     5  204.046440
# 10  Alagoas     5  197.763034
# 11  Alagoas     5  193.584556
# 12    Amapá     1  150.923603
# 13    Amapá     1  145.240808
# 14    Amapá     1  159.190266
# 15    Amapá     2  150.153145
# 16    Amapá     2  155.039635
# 17    Amapá     2  164.585944
# 18    Amapá     3  169.521117
# 19    Amapá     3  163.298306

# %%
location_by_year_frequency = locations_containing_high_violence_demos.groupby('location').count()
location_by_year_frequency['val'].describe()
# Out:
# count    18.000000
# mean      8.277778
# std       3.025491
# min       2.000000
# 25%       7.000000
# 50%      10.000000
# 75%      10.000000
# max      10.000000
# Name: val, dtype: float64

# %%
location_by_year_frequency
# Out:
#                      year  val
# location
# Acre                    2    2
# Alagoas                10   10
# Amapá                  10   10
# Amazonas               10   10
# Bahia                  10   10
# Ceará                  10   10
# Distrito Federal        3    3
# Espírito Santo         10   10
# Goiás                  10   10
# Mato Grosso             6    6
# Paraná                  6    6
# Paraíba                10   10
# Pará                   10   10
# Pernambuco             10   10
# Rio Grande do Norte    10   10
# Rio de Janeiro         10   10
# Roraima                 2    2
# Sergipe                10   10

# %%
country_filter = high_violence_death_rate_demos.groupby('country').count()['val']
country_filter
# Out:
# country
# Brazil    407
# Name: val, dtype: int64

# %%
location_filter = high_violence_death_rate_demos.groupby('location', as_index=False).count()
location_filter = location_filter[['location', 'val']]
location_filter
# Out:
#                location  val
# 0                  Acre    5
# 1               Alagoas   54
# 2                 Amapá   19
# 3              Amazonas   17
# 4                 Bahia   22
# 5                 Ceará   37
# 6      Distrito Federal    5
# 7        Espírito Santo   30
# 8                 Goiás   27
# 9           Mato Grosso    6
# 10               Paraná    6
# 11              Paraíba   30
# 12                 Pará   25
# 13           Pernambuco   40
# 14  Rio Grande do Norte   29
# 15       Rio de Janeiro   18
# 16              Roraima    2
# 17              Sergipe   35

# %%
gender_filter = high_violence_death_rate_demos.groupby('sex', as_index=False).count()
gender_filter
# Out:
#     sex  country  measure  location  age_sort  age  cause  year  val
# 0  Male      407      407       407       407  407    407   407  407

# %%
age_filter = high_violence_death_rate_demos.groupby('age', as_index=False).count()
age_filter = age_filter[['age', 'val']]
age_filter
# Out:
#         age  val
# 0  15 to 19   91
# 1  20 to 24  148
# 2  25 to 29  110
# 3  30 to 34   42
# 4  35 to 39   12
# 5  40 to 44    4

# %%
#we campare number of demographs (using deaths) vs the total number of demographs that have a higher iv homicide rate than 
#overall overall average.
newdf = df[df['measure'].str.contains("Deaths")]
print("Total number of sub groups: ", len(newdf))
print("Number of sub groups with higher violence death rate than diabetes death rate: ", len(high_violence_death_rate_demos))
print("Percentage of sub groups with higher violence death rate than diabetes death rate: ", round((100 * (len(high_violence_death_rate_demos)/len(newdf))), 3))
# Out:
# Total number of sub groups:  20520
# Number of sub groups with higher violence death rate than diabetes death rate:  407
# Percentage of sub groups with higher violence death rate than diabetes death rate:  1.983

# %% [markdown]
# ### Create table that lets us compare high homicde demographs to their corresponding diabetes death rates

# %%
diabetes_death = df[df['measure'].str.contains('Deaths') &
             df['cause'].str.contains('Diabetes')]

# %%
#create a new df using multiindex to combine the high homicide demographs with their corresponding diabetes deaths
#This cell get the diabetes rows
diabetes_death = diabetes_death[diabetes_death.set_index(['country','location', 'sex', 'age', 'year']).index.isin(high_violence_death_rate_demos.set_index(['country', 'location', 'sex', 'age', 'year']).index)]
newdf.shape
# Out:
# (20520, 9)

# %%
#combine the tables 
higher_violence_death_rate_with_diabetes = diabetes_death.append(high_violence_death_rate_demos)
higher_violence_death_rate_with_diabetes = higher_violence_death_rate_with_diabetes.sort_values(by=['location', 'sex', 'age', 'year'])
higher_violence_death_rate_with_diabetes.head(40)
# Out:
#        country measure location   sex  age_sort       age  \
# 476492  Brazil  Deaths     Acre  Male         2  15 to 19
# 476530  Brazil  Deaths     Acre  Male         2  15 to 19
# 469470  Brazil  Deaths     Acre  Male         2  20 to 24
# 473656  Brazil  Deaths     Acre  Male         2  20 to 24
# 476494  Brazil  Deaths     Acre  Male         2  20 to 24
# 476532  Brazil  Deaths     Acre  Male         2  20 to 24
# 469472  Brazil  Deaths     Acre  Male         2  25 to 29
# 473658  Brazil  Deaths     Acre  Male         2  25 to 29
# 476496  Brazil  Deaths     Acre  Male         2  25 to 29
# 476534  Brazil  Deaths     Acre  Male         2  25 to 29
# 456424  Brazil  Deaths  Alagoas  Male         2  15 to 19
# 456450  Brazil  Deaths  Alagoas  Male         2  15 to 19
# 456526  Brazil  Deaths  Alagoas  Male         2  15 to 19
# 457898  Brazil  Deaths  Alagoas  Male         2  15 to 19
# 459320  Brazil  Deaths  Alagoas  Male         2  15 to 19
# 460139  Brazil  Deaths  Alagoas  Male         2  15 to 19
# 459850  Brazil  Deaths  Alagoas  Male         2  15 to 19
# 459876  Brazil  Deaths  Alagoas  Male         2  15 to 19
# 465424  Brazil  Deaths  Alagoas  Male         2  15 to 19
# 469042  Brazil  Deaths  Alagoas  Male         2  15 to 19
# 465322  Brazil  Deaths  Alagoas  Male         2  15 to 19
# 465348  Brazil  Deaths  Alagoas  Male         2  15 to 19
# 490034  Brazil  Deaths  Alagoas  Male         2  15 to 19
# 490060  Brazil  Deaths  Alagoas  Male         2  15 to 19
# 473438  Brazil  Deaths  Alagoas  Male         2  15 to 19
# 473464  Brazil  Deaths  Alagoas  Male         2  15 to 19
# 498780  Brazil  Deaths  Alagoas  Male         2  15 to 19
# 498806  Brazil  Deaths  Alagoas  Male         2  15 to 19
# 485502  Brazil  Deaths  Alagoas  Male         2  15 to 19
# 485528  Brazil  Deaths  Alagoas  Male         2  15 to 19
# 456426  Brazil  Deaths  Alagoas  Male         2  20 to 24
# 456452  Brazil  Deaths  Alagoas  Male         2  20 to 24
# 456528  Brazil  Deaths  Alagoas  Male         2  20 to 24
# 457900  Brazil  Deaths  Alagoas  Male         2  20 to 24
# 459322  Brazil  Deaths  Alagoas  Male         2  20 to 24
# 460141  Brazil  Deaths  Alagoas  Male         2  20 to 24
# 459852  Brazil  Deaths  Alagoas  Male         2  20 to 24
# 459878  Brazil  Deaths  Alagoas  Male         2  20 to 24
# 465426  Brazil  Deaths  Alagoas  Male         2  20 to 24
# 469044  Brazil  Deaths  Alagoas  Male         2  20 to 24
#
#                          cause  year         val
# 476492       Diabetes mellitus  2017    0.634399
# 476530  Interpersonal violence  2017  149.263577
# 469470       Diabetes mellitus  2016    0.947388
# 473656  Interpersonal violence  2016  145.175626
# 476494       Diabetes mellitus  2017    0.930765
# 476532  Interpersonal violence  2017  156.661334
# 469472       Diabetes mellitus  2016    1.813549
# 473658  Interpersonal violence  2016  144.185752
# 476496       Diabetes mellitus  2017    1.793672
# 476534  Interpersonal violence  2017  160.462325
# 456424       Diabetes mellitus  2010    1.015013
# 456450  Interpersonal violence  2010  243.875534
# 456526       Diabetes mellitus  2011    1.025784
# 457898  Interpersonal violence  2011  257.942548
# 459320       Diabetes mellitus  2012    0.887067
# 460139  Interpersonal violence  2012  223.816475
# 459850       Diabetes mellitus  2013    0.809598
# 459876  Interpersonal violence  2013  211.938579
# 465424       Diabetes mellitus  2014    0.804928
# 469042  Interpersonal violence  2014  197.304388
# 465322       Diabetes mellitus  2015    0.691377
# 465348  Interpersonal violence  2015  165.143330
# 490034       Diabetes mellitus  2016    0.709413
# 490060  Interpersonal violence  2016  160.277432
# 473438       Diabetes mellitus  2017    0.644139
# 473464  Interpersonal violence  2017  155.775223
# 498780       Diabetes mellitus  2018    0.621174
# 498806  Interpersonal violence  2018  146.483785
# 485502       Diabetes mellitus  2019    0.603021
# 485528  Interpersonal violence  2019  141.369583
# 456426       Diabetes mellitus  2010    1.923242
# 456452  Interpersonal violence  2010  378.401649
# 456528       Diabetes mellitus  2011    1.896277
# 457900  Interpersonal violence  2011  390.170354
# 459322       Diabetes mellitus  2012    1.683295
# 460141  Interpersonal violence  2012  359.100583
# 459852       Diabetes mellitus  2013    1.687802
# 459878  Interpersonal violence  2013  349.784489
# 465426       Diabetes mellitus  2014    1.656574
# 469044  Interpersonal violence  2014  326.618712

# %%
higher_violence_death_rate_with_diabetes.shape
# Out:
# (814, 9)

# %% [markdown]
# ## YLL rate Exploration

# %% [markdown]
# ### Calculate overall diabetes average for YLLs

# %%
overall_diabetes_yll_avg = df[df['measure'].str.contains('YLL') &
                 df['cause'].str.contains('Diabetes')]
overall_diabetes_yll_avg = overall_diabetes_yll_avg['val'].mean()
overall_diabetes_yll_avg
# Out:
# 1757.314449649769

# %% [markdown]
# ### Create table of demographs with higher homicide rate

# %%
#get rows with higher homicide rate than overall_diabetes_avg
high_violence_yll_demos = df[df['measure'].str.contains('YLL') &
                  df['cause'].str.contains('Interpersonal violence')]

high_violence_yll_demos = high_violence_yll_demos[high_violence_yll_demos['val'] > overall_diabetes_yll_avg]
high_violence_yll_demos = high_violence_yll_demos.sort_values(by=['val'], ascending=False)
high_violence_yll_demos.shape
# Out:
# (2007, 9)

# %% [markdown]
# ## YLL Rate exploration

# %%
gender = high_violence_yll_demos.groupby(['sex'], as_index=False).agg({'val':'mean'})

# %%
gender.plot(x="sex", y="val", kind="bar")
plt.show()

# %%
age = high_violence_yll_demos.groupby(['age'], as_index=False).agg({'val':'mean'})

# %%
age.plot(x="age", y="val", kind="bar")
plt.show()

# %%
locations_containing_high_violence_demos = high_violence_yll_demos.groupby(['location', 'year'], as_index=False).agg({'year': 'count', 'val':'mean'})
locations_containing_high_violence_demos.head(20)
#38 demos in each region (for one year)
# Out:
#    location  year           val
# 0      Acre     7   4402.430072
# 1      Acre     7   4316.903107
# 2      Acre     8   4360.201613
# 3      Acre     7   4790.615410
# 4      Acre     7   4983.609557
# 5      Acre     7   5234.648765
# 6      Acre     8   5917.437723
# 7      Acre     8   6445.405210
# 8      Acre     7   5946.091302
# 9      Acre     7   5758.881480
# 10  Alagoas     9  11014.753228
# 11  Alagoas     9  11364.705102
# 12  Alagoas     9  10681.424780
# 13  Alagoas     9  10434.275952
# 14  Alagoas    10   9189.927501
# 15  Alagoas     9   9072.667703
# 16  Alagoas     9   8939.558503
# 17  Alagoas     9   8692.544535
# 18  Alagoas     9   8506.714146
# 19  Alagoas     9   8347.502701

# %%
location_by_year_frequency = locations_containing_high_violence_demos.groupby('location').count()
location_by_year_frequency['val'].describe()
# Out:
# count    27.0
# mean     10.0
# std       0.0
# min      10.0
# 25%      10.0
# 50%      10.0
# 75%      10.0
# max      10.0
# Name: val, dtype: float64

# %%
location_by_year_frequency
# Out:
#                      year  val
# location
# Acre                   10   10
# Alagoas                10   10
# Amapá                  10   10
# Amazonas               10   10
# Bahia                  10   10
# Ceará                  10   10
# Distrito Federal       10   10
# Espírito Santo         10   10
# Goiás                  10   10
# Maranhão               10   10
# Mato Grosso            10   10
# Mato Grosso do Sul     10   10
# Minas Gerais           10   10
# Paraná                 10   10
# Paraíba                10   10
# Pará                   10   10
# Pernambuco             10   10
# Piaui                  10   10
# Rio Grande do Norte    10   10
# Rio Grande do Sul      10   10
# Rio de Janeiro         10   10
# Rondônia               10   10
# Roraima                10   10
# Santa Catarina         10   10
# Sergipe                10   10
# São Paulo              10   10
# Tocantins              10   10

# %% [markdown]
# ### Take high_violence_ylls_demos and filter on the consistent demographs

# %%
high_violence_yll_demos.groupby('country').count()['val']
# Out:
# country
# Brazil    2007
# Name: val, dtype: int64

# %%
location_filter = high_violence_yll_demos.groupby('location', as_index=False).count()
location_filter = location_filter[['location', 'val']]
location_filter
# Out:
#                location  val
# 0                  Acre   73
# 1               Alagoas   91
# 2                 Amapá   75
# 3              Amazonas   80
# 4                 Bahia   89
# 5                 Ceará   85
# 6      Distrito Federal   63
# 7        Espírito Santo   81
# 8                 Goiás   78
# 9              Maranhão   84
# 10          Mato Grosso   82
# 11   Mato Grosso do Sul   72
# 12         Minas Gerais   60
# 13               Paraná   70
# 14              Paraíba   78
# 15                 Pará   90
# 16           Pernambuco   85
# 17                Piaui   53
# 18  Rio Grande do Norte   76
# 19    Rio Grande do Sul   61
# 20       Rio de Janeiro   71
# 21             Rondônia   89
# 22              Roraima   76
# 23       Santa Catarina   41
# 24              Sergipe   80
# 25            São Paulo   53
# 26            Tocantins   71

# %%
gender_filter = high_violence_yll_demos.groupby('sex', as_index=False).count()
gender_filter = gender_filter[['sex', 'val']]
gender_filter
# Out:
#     sex   val
# 0  Male  2007

# %%
age_filter = high_violence_yll_demos.groupby('age', as_index=False).count()
age_filter = age_filter[['age', 'val']]
age_filter
# Out:
#         age  val
# 0  15 to 19  270
# 1  20 to 24  270
# 2  25 to 29  270
# 3  30 to 34  270
# 4  35 to 39  261
# 5  40 to 44  246
# 6  45 to 49  214
# 7  50 to 54  150
# 8  55 to 59   55
# 9  60 to 64    1

# %%
#we campare number of demographs (using YLLs) vs the total number of demographs that have a higher iv homicide rate than 
#overall overall average.
newdf = df[df['measure'].str.contains("YLL")]
print("Total number of sub groups: ", len(newdf))
print("Number of sub groups with higher violence YLL rate than diabetes YLL rate: ", len(high_violence_yll_demos))
# Out:
# Total number of sub groups:  20520
# Number of sub groups with higher violence YLL rate than diabetes YLL rate:  2007

# %% [markdown]
# ### Create table that lets us compare high homicde demographs to their corresponding diabetes yll rates

# %%
diabetes_ylls = df[df['measure'].str.contains('YLL') &
             df['cause'].str.contains('Diabetes')]

# %%
#create a new df using multiindex to combine the high homicide demographs with their corresponding diabetes deaths
#This cell get the diabetes rows
diabetes_ylls = diabetes_ylls[diabetes_ylls.set_index(['country','location', 'sex', 'age', 'year']).index.isin(high_violence_yll_demos.set_index(['country', 'location', 'sex', 'age', 'year']).index)]
diabetes_ylls.shape
# Out:
# (2007, 9)

# %%
#combine the tables 
higher_violence_ylls_with_diabetes = diabetes_ylls.append(high_violence_yll_demos)
higher_violence_ylls_with_diabetes = higher_violence_ylls_with_diabetes.sort_values(by=['location', 'sex', 'age', 'year'])
higher_violence_ylls_with_diabetes.head(20)
# Out:
#        country                    measure location   sex  age_sort       age  \
# 456348  Brazil  YLLs (Years of Life Lost)     Acre  Male         2  15 to 19
# 456386  Brazil  YLLs (Years of Life Lost)     Acre  Male         2  15 to 19
# 458735  Brazil  YLLs (Years of Life Lost)     Acre  Male         2  15 to 19
# 458773  Brazil  YLLs (Years of Life Lost)     Acre  Male         2  15 to 19
# 460978  Brazil  YLLs (Years of Life Lost)     Acre  Male         2  15 to 19
# 461016  Brazil  YLLs (Years of Life Lost)     Acre  Male         2  15 to 19
# 464310  Brazil  YLLs (Years of Life Lost)     Acre  Male         2  15 to 19
# 464348  Brazil  YLLs (Years of Life Lost)     Acre  Male         2  15 to 19
# 467692  Brazil  YLLs (Years of Life Lost)     Acre  Male         2  15 to 19
# 472764  Brazil  YLLs (Years of Life Lost)     Acre  Male         2  15 to 19
# 472328  Brazil  YLLs (Years of Life Lost)     Acre  Male         2  15 to 19
# 472366  Brazil  YLLs (Years of Life Lost)     Acre  Male         2  15 to 19
# 467856  Brazil  YLLs (Years of Life Lost)     Acre  Male         2  15 to 19
# 474298  Brazil  YLLs (Years of Life Lost)     Acre  Male         2  15 to 19
# 480646  Brazil  YLLs (Years of Life Lost)     Acre  Male         2  15 to 19
# 480684  Brazil  YLLs (Years of Life Lost)     Acre  Male         2  15 to 19
# 488498  Brazil  YLLs (Years of Life Lost)     Acre  Male         2  15 to 19
# 488536  Brazil  YLLs (Years of Life Lost)     Acre  Male         2  15 to 19
# 487270  Brazil  YLLs (Years of Life Lost)     Acre  Male         2  15 to 19
# 487308  Brazil  YLLs (Years of Life Lost)     Acre  Male         2  15 to 19
#
#                          cause  year           val
# 456348       Diabetes mellitus  2010     36.295712
# 456386  Interpersonal violence  2010   5625.088880
# 458735       Diabetes mellitus  2011     37.459295
# 458773  Interpersonal violence  2011   5311.182626
# 460978       Diabetes mellitus  2012     32.618349
# 461016  Interpersonal violence  2012   5644.124860
# 464310       Diabetes mellitus  2013     32.968004
# 464348  Interpersonal violence  2013   5594.900991
# 467692       Diabetes mellitus  2014     33.043311
# 472764  Interpersonal violence  2014   5783.962561
# 472328       Diabetes mellitus  2015     37.432639
# 472366  Interpersonal violence  2015   6268.840991
# 467856       Diabetes mellitus  2016     47.401465
# 474298  Interpersonal violence  2016   9244.199145
# 480646       Diabetes mellitus  2017     45.307763
# 480684  Interpersonal violence  2017  10660.173774
# 488498       Diabetes mellitus  2018     39.160569
# 488536  Interpersonal violence  2018   7624.322094
# 487270       Diabetes mellitus  2019     37.780733
# 487308  Interpersonal violence  2019   7116.618184

# %%
higher_violence_ylls_with_diabetes.shape
# Out:
# (4014, 9)

# %% [markdown]
# ## DALY rate Exploration

# %% [markdown]
# ### Calculate overall diabetes average for DALYs

# %%
overall_diabetes_daly_avg = df[df['measure'].str.contains('DALY') &
                 df['cause'].str.contains('Diabetes')]
overall_diabetes_daly_avg = overall_diabetes_daly_avg['val'].mean()
overall_diabetes_daly_avg
# Out:
# 2894.154796739017

# %% [markdown]
# ### Create table of demographs with higher homicide rate

# %%
#get rows with higher homicide rate than overall_diabetes_avg
high_violence_daly_demos = df[df['measure'].str.contains('daly') &
                  df['cause'].str.contains('Interpersonal violence')]

high_violence_daly_demos = high_violence_daly_demos[high_violence_daly_demos['val'] > overall_diabetes_daly_avg]
high_violence_daly_demos = high_violence_daly_demos.sort_values(by=['val'], ascending=False)
high_violence_daly_demos.shape
# Out:
# (0, 9)

# %% [markdown]
# No demographs so we have nothing to explore with DALYs

# %% [markdown]
# # Results

# %% [markdown]
# ## Setup data for Map

# %%
state_dict = {'Paraná': 'PR',
 'Alagoas': 'AL',
 'Amazonas' : 'AM',
 'Rio de Janeiro' : 'RJ',
 'Paraíba': 'PB',
 'Roraima': 'RR',
 'Acre': 'AC',
 'Piaui': 'PI',
 'Amapá': 'AP',
 'Minas Gerais': 'MG',
 'Bahia': 'BA',
 'Pará': 'PA',
 'Sergipe': 'SE',
 'Mato Grosso': 'MT',
 'Ceará': 'CE',
 'Espírito Santo': 'ES',
 'Pernambuco': 'PE',
 'Tocantins': 'TO',
 'São Paulo': 'SP',
 'Goiás': 'GO',
 'Distrito Federal': 'DF',
 'Maranhão': 'MA',
 'Rondônia': 'RO',
 'Rio Grande do Norte': 'RN',
 'Mato Grosso do Sul': 'MS',
 'Santa Catarina': 'SC',
 'Rio Grande do Sul': 'RS'}

# %%
higher_violence_ylls_with_diabetes['state_code'] =  higher_violence_ylls_with_diabetes['location'].map(state_dict)
higher_violence_ylls_with_diabetes
# Out:
#        country                    measure   location   sex  age_sort  \
# 456348  Brazil  YLLs (Years of Life Lost)       Acre  Male         2
# 456386  Brazil  YLLs (Years of Life Lost)       Acre  Male         2
# 458735  Brazil  YLLs (Years of Life Lost)       Acre  Male         2
# 458773  Brazil  YLLs (Years of Life Lost)       Acre  Male         2
# 460978  Brazil  YLLs (Years of Life Lost)       Acre  Male         2
# ...        ...                        ...        ...   ...       ...
# 496126  Brazil  YLLs (Years of Life Lost)  Tocantins  Male         2
# 488042  Brazil  YLLs (Years of Life Lost)  Tocantins  Male         2
# 488080  Brazil  YLLs (Years of Life Lost)  Tocantins  Male         2
# 486586  Brazil  YLLs (Years of Life Lost)  Tocantins  Male         2
# 486624  Brazil  YLLs (Years of Life Lost)  Tocantins  Male         2
#
#              age                   cause  year          val state_code
# 456348  15 to 19       Diabetes mellitus  2010    36.295712         AC
# 456386  15 to 19  Interpersonal violence  2010  5625.088880         AC
# 458735  15 to 19       Diabetes mellitus  2011    37.459295         AC
# 458773  15 to 19  Interpersonal violence  2011  5311.182626         AC
# 460978  15 to 19       Diabetes mellitus  2012    32.618349         AC
# ...          ...                     ...   ...          ...        ...
# 496126  45 to 49  Interpersonal violence  2018  2249.003455         TO
# 488042  45 to 49       Diabetes mellitus  2019   692.890253         TO
# 488080  45 to 49  Interpersonal violence  2019  2209.536580         TO
# 486586  50 to 54       Diabetes mellitus  2016  1103.864153         TO
# 486624  50 to 54  Interpersonal violence  2016  1771.527173         TO
#
# [4014 rows x 10 columns]

# %%
state_vals = higher_violence_ylls_with_diabetes[['state_code', 'val']]
state_vals
# Out:
#        state_code          val
# 456348         AC    36.295712
# 456386         AC  5625.088880
# 458735         AC    37.459295
# 458773         AC  5311.182626
# 460978         AC    32.618349
# ...           ...          ...
# 496126         TO  2249.003455
# 488042         TO   692.890253
# 488080         TO  2209.536580
# 486586         TO  1103.864153
# 486624         TO  1771.527173
#
# [4014 rows x 2 columns]

# %%
violence_cases = state_vals.groupby('state_code', as_index=False).agg({'val': 'mean'})
violence_cases
# Out:
#    state_code          val
# 0          AC  2736.366465
# 1          AL  5269.121199
# 2          AM  3006.678355
# 3          AP  3244.671858
# 4          BA  3104.403574
# 5          CE  4057.853918
# 6          DF  2675.950296
# 7          ES  3898.773653
# 8          GO  3596.331825
# 9          MA  2539.187476
# 10         MG  2549.170982
# 11         MS  2106.745476
# 12         MT  2712.554117
# 13         PA  3394.538659
# 14         PB  3646.640459
# 15         PE  4288.117304
# 16         PI  1982.087810
# 17         PR  2758.320574
# 18         RJ  3362.532083
# 19         RN  4117.557152
# 20         RO  2715.948371
# 21         RR  2498.355169
# 22         RS  2533.145662
# 23         SC  1457.141303
# 24         SE  4164.248983
# 25         SP  1546.072986
# 26         TO  1954.284295

# %%
violence_cases = violence_cases.rename(columns={"state_code": "state"})
violence_cases
# Out:
#    state          val
# 0     AC  2736.366465
# 1     AL  5269.121199
# 2     AM  3006.678355
# 3     AP  3244.671858
# 4     BA  3104.403574
# 5     CE  4057.853918
# 6     DF  2675.950296
# 7     ES  3898.773653
# 8     GO  3596.331825
# 9     MA  2539.187476
# 10    MG  2549.170982
# 11    MS  2106.745476
# 12    MT  2712.554117
# 13    PA  3394.538659
# 14    PB  3646.640459
# 15    PE  4288.117304
# 16    PI  1982.087810
# 17    PR  2758.320574
# 18    RJ  3362.532083
# 19    RN  4117.557152
# 20    RO  2715.948371
# 21    RR  2498.355169
# 22    RS  2533.145662
# 23    SC  1457.141303
# 24    SE  4164.248983
# 25    SP  1546.072986
# 26    TO  1954.284295

# %%
newdf = high_violence_death_rate_demos.groupby(['location', 'year'], as_index=False).count()
newdf
# Out:
#     location  year  country  measure  sex  age_sort  age  cause  val
# 0       Acre  2016        2        2    2         2    2      2    2
# 1       Acre  2017        3        3    3         3    3      3    3
# 2    Alagoas  2010        6        6    6         6    6      6    6
# 3    Alagoas  2011        6        6    6         6    6      6    6
# 4    Alagoas  2012        6        6    6         6    6      6    6
# ..       ...   ...      ...      ...  ...       ...  ...    ...  ...
# 144  Sergipe  2015        4        4    4         4    4      4    4
# 145  Sergipe  2016        5        5    5         5    5      5    5
# 146  Sergipe  2017        5        5    5         5    5      5    5
# 147  Sergipe  2018        4        4    4         4    4      4    4
# 148  Sergipe  2019        4        4    4         4    4      4    4
#
# [149 rows x 9 columns]

# %%
df2 = newdf.groupby('location', as_index=False).count()
df2 = df2[['location', 'val']]
df2 = df2.rename(columns={"location": "state"})
df2
# Out:
#                   state  val
# 0                  Acre    2
# 1               Alagoas   10
# 2                 Amapá   10
# 3              Amazonas   10
# 4                 Bahia   10
# 5                 Ceará   10
# 6      Distrito Federal    3
# 7        Espírito Santo   10
# 8                 Goiás   10
# 9           Mato Grosso    6
# 10               Paraná    6
# 11              Paraíba   10
# 12                 Pará   10
# 13           Pernambuco   10
# 14  Rio Grande do Norte   10
# 15       Rio de Janeiro   10
# 16              Roraima    2
# 17              Sergipe   10

# %%
df.location.unique()
# Out:
# array(['Paraná', 'Alagoas', 'Amazonas', 'Rio de Janeiro', 'Paraíba',
#        'Roraima', 'Acre', 'Piaui', 'Amapá', 'Minas Gerais', 'Bahia',
#        'Pará', 'Sergipe', 'Mato Grosso', 'Ceará', 'Espírito Santo',
#        'Pernambuco', 'Tocantins', 'São Paulo', 'Goiás',
#        'Distrito Federal', 'Maranhão', 'Rondônia', 'Rio Grande do Norte',
#        'Mato Grosso do Sul', 'Santa Catarina', 'Rio Grande do Sul'],
#       dtype=object)

# %%
data = {'state':['Piaui', 'Minas Gerais', 'Tocantins', 'São Paulo', 'Maranhão', 'Rondônia', 'Mato Grosso do Sul', 'Santa Catarina', 'Rio Grande do Sul'], 'val': [0,0,0,0,0,0,0,0,0]}
df3 = pd.DataFrame(data=data)
df3
# Out:
#                 state  val
# 0               Piaui    0
# 1        Minas Gerais    0
# 2           Tocantins    0
# 3           São Paulo    0
# 4            Maranhão    0
# 5            Rondônia    0
# 6  Mato Grosso do Sul    0
# 7      Santa Catarina    0
# 8   Rio Grande do Sul    0

# %%
df3 = df2.append(df3, ignore_index=True)
df3
# Out:
#                   state  val
# 0                  Acre    2
# 1               Alagoas   10
# 2                 Amapá   10
# 3              Amazonas   10
# 4                 Bahia   10
# 5                 Ceará   10
# 6      Distrito Federal    3
# 7        Espírito Santo   10
# 8                 Goiás   10
# 9           Mato Grosso    6
# 10               Paraná    6
# 11              Paraíba   10
# 12                 Pará   10
# 13           Pernambuco   10
# 14  Rio Grande do Norte   10
# 15       Rio de Janeiro   10
# 16              Roraima    2
# 17              Sergipe   10
# 18                Piaui    0
# 19         Minas Gerais    0
# 20            Tocantins    0
# 21            São Paulo    0
# 22             Maranhão    0
# 23             Rondônia    0
# 24   Mato Grosso do Sul    0
# 25       Santa Catarina    0
# 26    Rio Grande do Sul    0

# %%
df3['state_code'] =  df3['state'].map(state_dict)
df3 = df3[['state_code', 'val']]
df3 = df3.rename(columns={"state_code": "state"})
df3
# Out:
#    state  val
# 0     AC    2
# 1     AL   10
# 2     AP   10
# 3     AM   10
# 4     BA   10
# 5     CE   10
# 6     DF    3
# 7     ES   10
# 8     GO   10
# 9     MT    6
# 10    PR    6
# 11    PB   10
# 12    PA   10
# 13    PE   10
# 14    RN   10
# 15    RJ   10
# 16    RR    2
# 17    SE   10
# 18    PI    0
# 19    MG    0
# 20    TO    0
# 21    SP    0
# 22    MA    0
# 23    RO    0
# 24    MS    0
# 25    SC    0
# 26    RS    0

# %% [markdown]
# ## Create Map

# %%
INFOS_UFS = gpd.read_file(BRAZIL_MAP_DATA, layer='lim_unidade_federacao_a')
INFOS_UFS.rename({'sigla': 'state'}, axis = 1, inplace = True)
BRASIL = INFOS_UFS.merge(df3, on='state', how = 'left')

fig, axs = plt.subplots(figsize = (12,8))

BRASIL.plot(ax = axs,column = 'val', cmap = 'Reds', legend = True, edgecolor = 'black', legend_kwds={'label': "Frequency of Presence of High-Crime Demographic Groups by Year", 'orientation': "vertical"})
plt.title("Presence of High Death Rate Demographic Groups due to Interpersonal Violence of Brazil by State", fontsize=16, y=1.05)

plt.tick_params(axis='both', which='both', bottom=False, left=False, labelbottom=False, labelleft=False) 

"""
Code Reference
Rodrigo Dutcosky (April 9 2020).Rodrigo Dutcosky. 
Available at: https://rodrigodutcosky.medium.com/mapas-coropl%C3%A9ticos-com-os-estados-do-brasil-em-python-b9b48c6db585 (Accessed 11/4/21).
"""

fig.savefig('../../../graphs/brazil_map_high_violence_demographs.png')
plt.show()
