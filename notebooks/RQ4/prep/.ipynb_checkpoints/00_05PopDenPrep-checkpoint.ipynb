# %% [markdown]
# # Population Density Prep

# %% [markdown]
# This notebook uses the 'estimatePop.xlsx' and 'LND02.xls' (for land area) to calculate population density for 2018.

# %% [markdown]
# # Setup

# %% [markdown]
# ## Imports

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ## Parameters

# %%
EST_POP_DATASET = "../../../data/RQ3/raw/estimatedPop.xlsx"
LAND_AREA_DATASET = "../../../data/RQ3/raw/LND02.xls"
PROCESSED_STATE_POP_DEN_DATASET = "../../../data/RQ3/processed/state_pop_den_df.csv"
PROCESSED_MSA_POP_DEN_DATASET = "../../../data/RQ3/processed/msa_pop_den_df.csv"

# %% [markdown]
# # Loading the Dataset

# %%
est_pop_df = pd.read_excel(EST_POP_DATASET, header=3, skipfooter=6) 
land_area_df = pd.read_excel(LAND_AREA_DATASET)

# %%
est_pop_df
# Out:
#                        Unnamed: 0     Census  Estimates Base       2010  \
# 0                   United States  308745538       308758105  309321666
# 1        .Autauga County, Alabama      54571           54597      54773
# 2        .Baldwin County, Alabama     182265          182265     183112
# 3        .Barbour County, Alabama      27457           27455      27327
# 4           .Bibb County, Alabama      22915           22915      22870
# ...                           ...        ...             ...        ...
# 3138  .Sweetwater County, Wyoming      43806           43806      43574
# 3139       .Teton County, Wyoming      21294           21298      21296
# 3140       .Uinta County, Wyoming      21118           21121      21089
# 3141    .Washakie County, Wyoming       8533            8528       8530
# 3142      .Weston County, Wyoming       7208            7208       7198
#
#            2011       2012       2013       2014       2015       2016  \
# 0     311556874  313830990  315993715  318301008  320635163  322941311
# 1         55227      54954      54727      54893      54864      55243
# 2        186558     190145     194885     199183     202939     207601
# 3         27341      27169      26937      26755      26283      25806
# 4         22745      22667      22521      22553      22566      22586
# ...         ...        ...        ...        ...        ...        ...
# 3138      43986      45002      45157      44948      44719      44222
# 3139      21414      21624      22315      22773      23047      23234
# 3140      20896      20996      20951      20822      20763      20682
# 3141       8449       8409       8413       8273       8278       8165
# 3142       7142       7077       7136       7138       7208       7220
#
#            2017       2018       2019
# 0     324985539  326687501  328239523
# 1         55390      55533      55869
# 2        212521     217855     223234
# 3         25157      24872      24686
# 4         22550      22367      22394
# ...         ...        ...        ...
# 3138      43464      42858      42343
# 3139      23384      23269      23464
# 3140      20431      20292      20226
# 3141       8010       7877       7805
# 3142       6968       6924       6927
#
# [3143 rows x 13 columns]

# %%
land_area_df
# Out:
#             Areaname  STCOU  LND010190F  LND010190D  LND010190N1  LND010190N2  \
# 0      UNITED STATES      0           0  3787425.08            0            0
# 1            ALABAMA   1000           0    52422.94            0            0
# 2        Autauga, AL   1001           0      604.49            0            0
# 3        Baldwin, AL   1003           0     2027.08            0            0
# 4        Barbour, AL   1005           0      904.59            0            0
# ...              ...    ...         ...         ...          ...          ...
# 3193  Sweetwater, WY  56037           0    10491.73            0            0
# 3194       Teton, WY  56039           0     4221.96            0            0
# 3195       Uinta, WY  56041           0     2087.66            0            0
# 3196    Washakie, WY  56043           0     2242.85            0            0
# 3197      Weston, WY  56045           0     2400.13            0            0
#
#       LND010200F  LND010200D  LND010200N1  LND010200N2  ...  LND110210N1  \
# 0              0  3794083.06            0            0  ...            0
# 1              0    52419.02            0            0  ...            0
# 2              0      604.45            0            0  ...            0
# 3              0     2026.93            0            0  ...            0
# 4              0      904.52            0            0  ...            0
# ...          ...         ...          ...          ...  ...          ...
# 3193           0    10491.17            0            0  ...            0
# 3194           0     4221.80            0            0  ...            0
# 3195           0     2087.56            0            0  ...            0
# 3196           0     2242.75            0            0  ...            0
# 3197           0     2400.07            0            0  ...            0
#
#       LND110210N2  LND210190F  LND210190D  LND210190N1  LND210190N2  \
# 0               0           0   251083.35            0            0
# 1               0           0     1672.71            0            0
# 2               0           0        8.48            0            0
# 3               0           0      430.55            0            0
# 4               0           0       19.59            0            0
# ...           ...         ...         ...          ...          ...
# 3193            0           0       65.86            0            0
# 3194            0           0      214.02            0            0
# 3195            0           0        5.91            0            0
# 3196            0           0        2.69            0            0
# 3197            0           0        2.21            0            0
#
#       LND210200F  LND210200D  LND210200N1  LND210200N2
# 0              0   256644.62            0            0
# 1              0     1675.01            0            0
# 2              0        8.48            0            0
# 3              0      430.58            0            0
# 4              0       19.61            0            0
# ...          ...         ...          ...          ...
# 3193           0       65.87            0            0
# 3194           0      214.04            0            0
# 3195           0        5.90            0            0
# 3196           0        2.69            0            0
# 3197           0        2.21            0            0
#
# [3198 rows x 34 columns]

# %% [markdown]
# ### First get the estimated population for 2018

# %%
est_pop_df.tail()
# Out:
#                        Unnamed: 0  Census  Estimates Base   2010   2011  \
# 3138  .Sweetwater County, Wyoming   43806           43806  43574  43986
# 3139       .Teton County, Wyoming   21294           21298  21296  21414
# 3140       .Uinta County, Wyoming   21118           21121  21089  20896
# 3141    .Washakie County, Wyoming    8533            8528   8530   8449
# 3142      .Weston County, Wyoming    7208            7208   7198   7142
#
#        2012   2013   2014   2015   2016   2017   2018   2019
# 3138  45002  45157  44948  44719  44222  43464  42858  42343
# 3139  21624  22315  22773  23047  23234  23384  23269  23464
# 3140  20996  20951  20822  20763  20682  20431  20292  20226
# 3141   8409   8413   8273   8278   8165   8010   7877   7805
# 3142   7077   7136   7138   7208   7220   6968   6924   6927

# %%
est_pop_df.columns
# Out:
# Index([    'Unnamed: 0',         'Census', 'Estimates Base',             2010,
#                    2011,             2012,             2013,             2014,
#                    2015,             2016,             2017,             2018,
#                    2019],
#       dtype='object')

# %%
est_pop_df = est_pop_df.rename(columns = {"Unnamed: 0": "Area", est_pop_df[est_pop_df.columns[11]].name: "2018"})
est_pop_df.head()
# Out:
#                        Area     Census  Estimates Base       2010       2011  \
# 0             United States  308745538       308758105  309321666  311556874
# 1  .Autauga County, Alabama      54571           54597      54773      55227
# 2  .Baldwin County, Alabama     182265          182265     183112     186558
# 3  .Barbour County, Alabama      27457           27455      27327      27341
# 4     .Bibb County, Alabama      22915           22915      22870      22745
#
#         2012       2013       2014       2015       2016       2017  \
# 0  313830990  315993715  318301008  320635163  322941311  324985539
# 1      54954      54727      54893      54864      55243      55390
# 2     190145     194885     199183     202939     207601     212521
# 3      27169      26937      26755      26283      25806      25157
# 4      22667      22521      22553      22566      22586      22550
#
#         2018       2019
# 0  326687501  328239523
# 1      55533      55869
# 2     217855     223234
# 3      24872      24686
# 4      22367      22394

# %%
key_cols = ['Area', '2018']
est_pop_df = est_pop_df[key_cols]
est_pop_df.head()
# Out:
#                        Area       2018
# 0             United States  326687501
# 1  .Autauga County, Alabama      55533
# 2  .Baldwin County, Alabama     217855
# 3  .Barbour County, Alabama      24872
# 4     .Bibb County, Alabama      22367

# %%
#Copy for later work
est_pop_df2 = est_pop_df.copy()

# %% [markdown]
# ### Store the US population estimate as a whole

# %%
US_pop = est_pop_df['2018'].iloc[0]
US_pop
# Out:
# 326687501

# %% [markdown]
# ### Create a dataset for the states

# %%
#Now remove US because we don't need it for the states
est_pop_df = est_pop_df.drop(0)
est_pop_df.head()
# Out:
#                        Area    2018
# 1  .Autauga County, Alabama   55533
# 2  .Baldwin County, Alabama  217855
# 3  .Barbour County, Alabama   24872
# 4     .Bibb County, Alabama   22367
# 5   .Blount County, Alabama   57771

# %%
#Need to process Area strings and groupby county
est_pop_df['Area'] = est_pop_df['Area'].str.split(',').str[1]
est_pop_df['Area'] = est_pop_df['Area'].str.upper()
est_pop_df['Area'] = est_pop_df['Area'].str.strip()
est_pop_df
# Out:
#          Area    2018
# 1     ALABAMA   55533
# 2     ALABAMA  217855
# 3     ALABAMA   24872
# 4     ALABAMA   22367
# 5     ALABAMA   57771
# ...       ...     ...
# 3138  WYOMING   42858
# 3139  WYOMING   23269
# 3140  WYOMING   20292
# 3141  WYOMING    7877
# 3142  WYOMING    6924
#
# [3142 rows x 2 columns]

# %%
est_pop_df = est_pop_df.rename(columns = {"Area": "State", "2018": "Population"})
est_pop_df
# Out:
#         State  Population
# 1     ALABAMA       55533
# 2     ALABAMA      217855
# 3     ALABAMA       24872
# 4     ALABAMA       22367
# 5     ALABAMA       57771
# ...       ...         ...
# 3138  WYOMING       42858
# 3139  WYOMING       23269
# 3140  WYOMING       20292
# 3141  WYOMING        7877
# 3142  WYOMING        6924
#
# [3142 rows x 2 columns]

# %%
est_pop_df = est_pop_df.groupby(['State']).sum()
est_pop_df
# Out:
#                       Population
# State
# ALABAMA                  4887681
# ALASKA                    735139
# ARIZONA                  7158024
# ARKANSAS                 3009733
# CALIFORNIA              39461588
# COLORADO                 5691287
# CONNECTICUT              3571520
# DELAWARE                  965479
# DISTRICT OF COLUMBIA      701547
# FLORIDA                 21244317
# GEORGIA                 10511131
# HAWAII                   1420593
# IDAHO                    1750536
# ILLINOIS                12723071
# INDIANA                  6695497
# IOWA                     3148618
# KANSAS                   2911359
# KENTUCKY                 4461153
# LOUISIANA                4659690
# MAINE                    1339057
# MARYLAND                 6035802
# MASSACHUSETTS            6882635
# MICHIGAN                 9984072
# MINNESOTA                5606249
# MISSISSIPPI              2981020
# MISSOURI                 6121623
# MONTANA                  1060665
# NEBRASKA                 1925614
# NEVADA                   3027341
# NEW HAMPSHIRE            1353465
# NEW JERSEY               8886025
# NEW MEXICO               2092741
# NEW YORK                19530351
# NORTH CAROLINA          10381615
# NORTH DAKOTA              758080
# OHIO                    11676341
# OKLAHOMA                 3940235
# OREGON                   4181886
# PENNSYLVANIA            12800922
# RHODE ISLAND             1058287
# SOUTH CAROLINA           5084156
# SOUTH DAKOTA              878698
# TENNESSEE                6771631
# TEXAS                   28628666
# UTAH                     3153550
# VERMONT                   624358
# VIRGINIA                 8501286
# WASHINGTON               7523869
# WEST VIRGINIA            1804291
# WISCONSIN                5807406
# WYOMING                   577601

# %% [markdown]
# ### Now preparing land area

# %%
land_area_df
# Out:
#             Areaname  STCOU  LND010190F  LND010190D  LND010190N1  LND010190N2  \
# 0      UNITED STATES      0           0  3787425.08            0            0
# 1            ALABAMA   1000           0    52422.94            0            0
# 2        Autauga, AL   1001           0      604.49            0            0
# 3        Baldwin, AL   1003           0     2027.08            0            0
# 4        Barbour, AL   1005           0      904.59            0            0
# ...              ...    ...         ...         ...          ...          ...
# 3193  Sweetwater, WY  56037           0    10491.73            0            0
# 3194       Teton, WY  56039           0     4221.96            0            0
# 3195       Uinta, WY  56041           0     2087.66            0            0
# 3196    Washakie, WY  56043           0     2242.85            0            0
# 3197      Weston, WY  56045           0     2400.13            0            0
#
#       LND010200F  LND010200D  LND010200N1  LND010200N2  ...  LND110210N1  \
# 0              0  3794083.06            0            0  ...            0
# 1              0    52419.02            0            0  ...            0
# 2              0      604.45            0            0  ...            0
# 3              0     2026.93            0            0  ...            0
# 4              0      904.52            0            0  ...            0
# ...          ...         ...          ...          ...  ...          ...
# 3193           0    10491.17            0            0  ...            0
# 3194           0     4221.80            0            0  ...            0
# 3195           0     2087.56            0            0  ...            0
# 3196           0     2242.75            0            0  ...            0
# 3197           0     2400.07            0            0  ...            0
#
#       LND110210N2  LND210190F  LND210190D  LND210190N1  LND210190N2  \
# 0               0           0   251083.35            0            0
# 1               0           0     1672.71            0            0
# 2               0           0        8.48            0            0
# 3               0           0      430.55            0            0
# 4               0           0       19.59            0            0
# ...           ...         ...         ...          ...          ...
# 3193            0           0       65.86            0            0
# 3194            0           0      214.02            0            0
# 3195            0           0        5.91            0            0
# 3196            0           0        2.69            0            0
# 3197            0           0        2.21            0            0
#
#       LND210200F  LND210200D  LND210200N1  LND210200N2
# 0              0   256644.62            0            0
# 1              0     1675.01            0            0
# 2              0        8.48            0            0
# 3              0      430.58            0            0
# 4              0       19.61            0            0
# ...          ...         ...          ...          ...
# 3193           0       65.87            0            0
# 3194           0      214.04            0            0
# 3195           0        5.90            0            0
# 3196           0        2.69            0            0
# 3197           0        2.21            0            0
#
# [3198 rows x 34 columns]

# %%
key_cols = ['Areaname','LND110210D'] # 'LND110210D' is the column name for "land area in square miles 2010"
land_area_df = land_area_df[key_cols]
land_area_df2 = land_area_df.copy()
land_area_df = land_area_df.rename(columns = {"Areaname": "State", "LND110210D": "Land Area"})
land_area_df.head()
# Out:
#            State   Land Area
# 0  UNITED STATES  3531905.43
# 1        ALABAMA    50645.33
# 2    Autauga, AL      594.44
# 3    Baldwin, AL     1589.78
# 4    Barbour, AL      884.88

# %%
US_land_area = land_area_df['Land Area'].iloc[0]
US_land_area
# Out:
# 3531905.43

# %%
land_area_df = land_area_df.drop(0)
land_area_df
# Out:
#                State  Land Area
# 1            ALABAMA   50645.33
# 2        Autauga, AL     594.44
# 3        Baldwin, AL    1589.78
# 4        Barbour, AL     884.88
# 5           Bibb, AL     622.58
# ...              ...        ...
# 3193  Sweetwater, WY   10426.65
# 3194       Teton, WY    3995.38
# 3195       Uinta, WY    2081.26
# 3196    Washakie, WY    2238.55
# 3197      Weston, WY    2398.09
#
# [3197 rows x 2 columns]

# %%
land_area_df = land_area_df[~land_area_df['State'].str.contains(',')]
land_area_df
# Out:
#                      State  Land Area
# 1                  ALABAMA   50645.33
# 69                  ALASKA  570640.95
# 99                 ARIZONA  113594.08
# 115               ARKANSAS   52035.48
# 191             CALIFORNIA  155779.22
# 250               COLORADO  103641.89
# 315            CONNECTICUT    4842.36
# 324               DELAWARE    1948.54
# 328   DISTRICT OF COLUMBIA      61.05
# 329   District of Columbia      61.05
# 330                FLORIDA   53624.76
# 398                GEORGIA   57513.49
# 558                 HAWAII    6422.63
# 564                  IDAHO   82643.12
# 609               ILLINOIS   55518.93
# 712                INDIANA   35826.11
# 805                   IOWA   55857.13
# 905                 KANSAS   81758.72
# 1011              KENTUCKY   39486.34
# 1132             LOUISIANA   43203.90
# 1197                 MAINE   30842.92
# 1214              MARYLAND    9707.24
# 1239         MASSACHUSETTS    7800.06
# 1254              MICHIGAN   56538.90
# 1338             MINNESOTA   79626.74
# 1426           MISSISSIPPI   46923.27
# 1509              MISSOURI   68741.52
# 1625               MONTANA  145545.80
# 1683              NEBRASKA   76824.17
# 1777                NEVADA  109781.18
# 1795         NEW HAMPSHIRE    8952.65
# 1806            NEW JERSEY    7354.22
# 1828            NEW MEXICO  121298.15
# 1862              NEW YORK   47126.40
# 1925        NORTH CAROLINA   48617.91
# 2026          NORTH DAKOTA   69000.80
# 2080                  OHIO   40860.69
# 2169              OKLAHOMA   68594.92
# 2247                OREGON   95988.01
# 2284          PENNSYLVANIA   44742.70
# 2352          RHODE ISLAND    1033.81
# 2358        SOUTH CAROLINA   30060.70
# 2405          SOUTH DAKOTA   75811.00
# 2472             TENNESSEE   41234.90
# 2568                 TEXAS  261231.71
# 2823                  UTAH   82169.62
# 2853               VERMONT    9216.66
# 2868              VIRGINIA   39490.09
# 3005            WASHINGTON   66455.52
# 3045         WEST VIRGINIA   24038.21
# 3101             WISCONSIN   54157.80
# 3174               WYOMING   97093.14

# %%
#District of columbia has been included twice, so we need to remove one
land_area_df = land_area_df.drop(329)
land_area_df.shape
# Out:
# (51, 2)

# %%
land_area_df = land_area_df.set_index('State')
land_area_df
# Out:
#                       Land Area
# State
# ALABAMA                50645.33
# ALASKA                570640.95
# ARIZONA               113594.08
# ARKANSAS               52035.48
# CALIFORNIA            155779.22
# COLORADO              103641.89
# CONNECTICUT             4842.36
# DELAWARE                1948.54
# DISTRICT OF COLUMBIA      61.05
# FLORIDA                53624.76
# GEORGIA                57513.49
# HAWAII                  6422.63
# IDAHO                  82643.12
# ILLINOIS               55518.93
# INDIANA                35826.11
# IOWA                   55857.13
# KANSAS                 81758.72
# KENTUCKY               39486.34
# LOUISIANA              43203.90
# MAINE                  30842.92
# MARYLAND                9707.24
# MASSACHUSETTS           7800.06
# MICHIGAN               56538.90
# MINNESOTA              79626.74
# MISSISSIPPI            46923.27
# MISSOURI               68741.52
# MONTANA               145545.80
# NEBRASKA               76824.17
# NEVADA                109781.18
# NEW HAMPSHIRE           8952.65
# NEW JERSEY              7354.22
# NEW MEXICO            121298.15
# NEW YORK               47126.40
# NORTH CAROLINA         48617.91
# NORTH DAKOTA           69000.80
# OHIO                   40860.69
# OKLAHOMA               68594.92
# OREGON                 95988.01
# PENNSYLVANIA           44742.70
# RHODE ISLAND            1033.81
# SOUTH CAROLINA         30060.70
# SOUTH DAKOTA           75811.00
# TENNESSEE              41234.90
# TEXAS                 261231.71
# UTAH                   82169.62
# VERMONT                 9216.66
# VIRGINIA               39490.09
# WASHINGTON             66455.52
# WEST VIRGINIA          24038.21
# WISCONSIN              54157.80
# WYOMING                97093.14

# %% [markdown]
# ### Create Population density data

# %%
df = pd.DataFrame(index=est_pop_df.index)

df['Population'] = est_pop_df['Population']
df['Land Area'] = land_area_df['Land Area']
df
# Out:
#                       Population  Land Area
# State
# ALABAMA                  4887681   50645.33
# ALASKA                    735139  570640.95
# ARIZONA                  7158024  113594.08
# ARKANSAS                 3009733   52035.48
# CALIFORNIA              39461588  155779.22
# COLORADO                 5691287  103641.89
# CONNECTICUT              3571520    4842.36
# DELAWARE                  965479    1948.54
# DISTRICT OF COLUMBIA      701547      61.05
# FLORIDA                 21244317   53624.76
# GEORGIA                 10511131   57513.49
# HAWAII                   1420593    6422.63
# IDAHO                    1750536   82643.12
# ILLINOIS                12723071   55518.93
# INDIANA                  6695497   35826.11
# IOWA                     3148618   55857.13
# KANSAS                   2911359   81758.72
# KENTUCKY                 4461153   39486.34
# LOUISIANA                4659690   43203.90
# MAINE                    1339057   30842.92
# MARYLAND                 6035802    9707.24
# MASSACHUSETTS            6882635    7800.06
# MICHIGAN                 9984072   56538.90
# MINNESOTA                5606249   79626.74
# MISSISSIPPI              2981020   46923.27
# MISSOURI                 6121623   68741.52
# MONTANA                  1060665  145545.80
# NEBRASKA                 1925614   76824.17
# NEVADA                   3027341  109781.18
# NEW HAMPSHIRE            1353465    8952.65
# NEW JERSEY               8886025    7354.22
# NEW MEXICO               2092741  121298.15
# NEW YORK                19530351   47126.40
# NORTH CAROLINA          10381615   48617.91
# NORTH DAKOTA              758080   69000.80
# OHIO                    11676341   40860.69
# OKLAHOMA                 3940235   68594.92
# OREGON                   4181886   95988.01
# PENNSYLVANIA            12800922   44742.70
# RHODE ISLAND             1058287    1033.81
# SOUTH CAROLINA           5084156   30060.70
# SOUTH DAKOTA              878698   75811.00
# TENNESSEE                6771631   41234.90
# TEXAS                   28628666  261231.71
# UTAH                     3153550   82169.62
# VERMONT                   624358    9216.66
# VIRGINIA                 8501286   39490.09
# WASHINGTON               7523869   66455.52
# WEST VIRGINIA            1804291   24038.21
# WISCONSIN                5807406   54157.80
# WYOMING                   577601   97093.14

# %%
state_pop_den_df = land_area_df.merge(est_pop_df, on='State', how='left')
state_pop_den_df
# Out:
#                       Land Area  Population
# State
# ALABAMA                50645.33     4887681
# ALASKA                570640.95      735139
# ARIZONA               113594.08     7158024
# ARKANSAS               52035.48     3009733
# CALIFORNIA            155779.22    39461588
# COLORADO              103641.89     5691287
# CONNECTICUT             4842.36     3571520
# DELAWARE                1948.54      965479
# DISTRICT OF COLUMBIA      61.05      701547
# FLORIDA                53624.76    21244317
# GEORGIA                57513.49    10511131
# HAWAII                  6422.63     1420593
# IDAHO                  82643.12     1750536
# ILLINOIS               55518.93    12723071
# INDIANA                35826.11     6695497
# IOWA                   55857.13     3148618
# KANSAS                 81758.72     2911359
# KENTUCKY               39486.34     4461153
# LOUISIANA              43203.90     4659690
# MAINE                  30842.92     1339057
# MARYLAND                9707.24     6035802
# MASSACHUSETTS           7800.06     6882635
# MICHIGAN               56538.90     9984072
# MINNESOTA              79626.74     5606249
# MISSISSIPPI            46923.27     2981020
# MISSOURI               68741.52     6121623
# MONTANA               145545.80     1060665
# NEBRASKA               76824.17     1925614
# NEVADA                109781.18     3027341
# NEW HAMPSHIRE           8952.65     1353465
# NEW JERSEY              7354.22     8886025
# NEW MEXICO            121298.15     2092741
# NEW YORK               47126.40    19530351
# NORTH CAROLINA         48617.91    10381615
# NORTH DAKOTA           69000.80      758080
# OHIO                   40860.69    11676341
# OKLAHOMA               68594.92     3940235
# OREGON                 95988.01     4181886
# PENNSYLVANIA           44742.70    12800922
# RHODE ISLAND            1033.81     1058287
# SOUTH CAROLINA         30060.70     5084156
# SOUTH DAKOTA           75811.00      878698
# TENNESSEE              41234.90     6771631
# TEXAS                 261231.71    28628666
# UTAH                   82169.62     3153550
# VERMONT                 9216.66      624358
# VIRGINIA               39490.09     8501286
# WASHINGTON             66455.52     7523869
# WEST VIRGINIA          24038.21     1804291
# WISCONSIN              54157.80     5807406
# WYOMING                97093.14      577601

# %%
state_pop_den_df['Population Density'] = state_pop_den_df['Population'] / state_pop_den_df['Land Area']
state_pop_den_df = state_pop_den_df.drop(['Land Area', 'Population'], axis = 1)
state_pop_den_df
# Out:
#                       Population Density
# State
# ALABAMA                        96.508029
# ALASKA                          1.288269
# ARIZONA                        63.014058
# ARKANSAS                       57.840016
# CALIFORNIA                    253.317407
# COLORADO                       54.912999
# CONNECTICUT                   737.557720
# DELAWARE                      495.488417
# DISTRICT OF COLUMBIA        11491.351351
# FLORIDA                       396.166193
# GEORGIA                       182.759401
# HAWAII                        221.185558
# IDAHO                          21.181872
# ILLINOIS                      229.166358
# INDIANA                       186.888752
# IOWA                           56.369133
# KANSAS                         35.609156
# KENTUCKY                      112.979653
# LOUISIANA                     107.853458
# MAINE                          43.415377
# MARYLAND                      621.783535
# MASSACHUSETTS                 882.382315
# MICHIGAN                      176.587659
# MINNESOTA                      70.406612
# MISSISSIPPI                    63.529673
# MISSOURI                       89.052773
# MONTANA                         7.287500
# NEBRASKA                       25.065211
# NEVADA                         27.576138
# NEW HAMPSHIRE                 151.180377
# NEW JERSEY                   1208.289254
# NEW MEXICO                     17.252868
# NEW YORK                      414.424845
# NORTH CAROLINA                213.534786
# NORTH DAKOTA                   10.986539
# OHIO                          285.759761
# OKLAHOMA                       57.442082
# OREGON                         43.566754
# PENNSYLVANIA                  286.100794
# RHODE ISLAND                 1023.676498
# SOUTH CAROLINA                169.129661
# SOUTH DAKOTA                   11.590640
# TENNESSEE                     164.220866
# TEXAS                         109.591083
# UTAH                           38.378539
# VERMONT                        67.742327
# VIRGINIA                      215.276440
# WASHINGTON                    113.216615
# WEST VIRGINIA                  75.059291
# WISCONSIN                     107.231202
# WYOMING                         5.948937

# %% [markdown]
# ### Create a dataset for the counties

# %%
est_pop_df2 = est_pop_df2.drop(0)
est_pop_df2.head()
# Out:
#                        Area    2018
# 1  .Autauga County, Alabama   55533
# 2  .Baldwin County, Alabama  217855
# 3  .Barbour County, Alabama   24872
# 4     .Bibb County, Alabama   22367
# 5   .Blount County, Alabama   57771

# %%
#Need to process Area strings and groupby county
new_df = est_pop_df2['Area'].str.split(',', n = 1, expand = True)
est_pop_df2["County/City"] = new_df[0] 
est_pop_df2["State"] = new_df[1]

# %%
est_pop_df2 = est_pop_df2.drop(['Area'], axis=1)
est_pop_df2 = est_pop_df2.rename(columns = {"2018": "Population"})
est_pop_df2 = est_pop_df2[['County/City', 'State', 'Population']]
est_pop_df2['State'] = est_pop_df2['State'].str.strip()
est_pop_df2
# Out:
#              County/City    State  Population
# 1        .Autauga County  Alabama       55533
# 2        .Baldwin County  Alabama      217855
# 3        .Barbour County  Alabama       24872
# 4           .Bibb County  Alabama       22367
# 5         .Blount County  Alabama       57771
# ...                  ...      ...         ...
# 3138  .Sweetwater County  Wyoming       42858
# 3139       .Teton County  Wyoming       23269
# 3140       .Uinta County  Wyoming       20292
# 3141    .Washakie County  Wyoming        7877
# 3142      .Weston County  Wyoming        6924
#
# [3142 rows x 3 columns]

# %%
est_pop_df2['County/City'] = est_pop_df2['County/City'].str.replace(".", "", regex = True)
est_pop_df2
# Out:
#             County/City    State  Population
# 1        Autauga County  Alabama       55533
# 2        Baldwin County  Alabama      217855
# 3        Barbour County  Alabama       24872
# 4           Bibb County  Alabama       22367
# 5         Blount County  Alabama       57771
# ...                 ...      ...         ...
# 3138  Sweetwater County  Wyoming       42858
# 3139       Teton County  Wyoming       23269
# 3140       Uinta County  Wyoming       20292
# 3141    Washakie County  Wyoming        7877
# 3142      Weston County  Wyoming        6924
#
# [3142 rows x 3 columns]

# %% [markdown]
# ### Get land area

# %%
land_area_df2
# Out:
#             Areaname  LND110210D
# 0      UNITED STATES  3531905.43
# 1            ALABAMA    50645.33
# 2        Autauga, AL      594.44
# 3        Baldwin, AL     1589.78
# 4        Barbour, AL      884.88
# ...              ...         ...
# 3193  Sweetwater, WY    10426.65
# 3194       Teton, WY     3995.38
# 3195       Uinta, WY     2081.26
# 3196    Washakie, WY     2238.55
# 3197      Weston, WY     2398.09
#
# [3198 rows x 2 columns]

# %%
land_area_df2[land_area_df2['Areaname'].str.contains(',')].sum()
# Out:
# Areaname      Autauga, ALBaldwin, ALBarbour, ALBibb, ALBloun...
# LND110210D                                           3531845.96
# dtype: object

# %%
land_area_df2 = land_area_df2.rename(columns = {"Areaname": "County/City", "LND110210D": "Land Area"})
land_area_df2 = land_area_df2[land_area_df2['County/City'].str.contains(',')]
land_area_df2.head()
# Out:
#    County/City  Land Area
# 2  Autauga, AL     594.44
# 3  Baldwin, AL    1589.78
# 4  Barbour, AL     884.88
# 5     Bibb, AL     622.58
# 6   Blount, AL     644.78

# %% [markdown]
# We can see that that 52 rows have been removed (51 states and America itself)

# %%
#Now we have to separate the county name and state name
new_df = land_area_df2['County/City'].str.split(',', n = 1, expand = True)
land_area_df2["County/City"] = new_df[0] 
land_area_df2["State Code"] = new_df[1] 
land_area_df2
# Out:
#      County/City  Land Area State Code
# 2        Autauga     594.44         AL
# 3        Baldwin    1589.78         AL
# 4        Barbour     884.88         AL
# 5           Bibb     622.58         AL
# 6         Blount     644.78         AL
# ...          ...        ...        ...
# 3193  Sweetwater   10426.65         WY
# 3194       Teton    3995.38         WY
# 3195       Uinta    2081.26         WY
# 3196    Washakie    2238.55         WY
# 3197      Weston    2398.09         WY
#
# [3145 rows x 3 columns]

# %%
land_area_df2 = land_area_df2.reset_index(drop=True)
land_area_df2['State Code'] = land_area_df2['State Code'].str.strip()
land_area_df2
# Out:
#      County/City  Land Area State Code
# 0        Autauga     594.44         AL
# 1        Baldwin    1589.78         AL
# 2        Barbour     884.88         AL
# 3           Bibb     622.58         AL
# 4         Blount     644.78         AL
# ...          ...        ...        ...
# 3140  Sweetwater   10426.65         WY
# 3141       Teton    3995.38         WY
# 3142       Uinta    2081.26         WY
# 3143    Washakie    2238.55         WY
# 3144      Weston    2398.09         WY
#
# [3145 rows x 3 columns]

# %%
us_state_abbrev = {
    'Alabama': 'AL',
    'Alaska': 'AK',
    'American Samoa': 'AS',
    'Arizona': 'AZ',
    'Arkansas': 'AR',
    'California': 'CA',
    'Colorado': 'CO',
    'Connecticut': 'CT',
    'Delaware': 'DE',
    'District of Columbia': 'DC',
    'Florida': 'FL',
    'Georgia': 'GA',
    'Guam': 'GU',
    'Hawaii': 'HI',
    'Idaho': 'ID',
    'Illinois': 'IL',
    'Indiana': 'IN',
    'Iowa': 'IA',
    'Kansas': 'KS',
    'Kentucky': 'KY',
    'Louisiana': 'LA',
    'Maine': 'ME',
    'Maryland': 'MD',
    'Massachusetts': 'MA',
    'Michigan': 'MI',
    'Minnesota': 'MN',
    'Mississippi': 'MS',
    'Missouri': 'MO',
    'Montana': 'MT',
    'Nebraska': 'NE',
    'Nevada': 'NV',
    'New Hampshire': 'NH',
    'New Jersey': 'NJ',
    'New Mexico': 'NM',
    'New York': 'NY',
    'North Carolina': 'NC',
    'North Dakota': 'ND',
    'Northern Mariana Islands':'MP',
    'Ohio': 'OH',
    'Oklahoma': 'OK',
    'Oregon': 'OR',
    'Pennsylvania': 'PA',
    'Puerto Rico': 'PR',
    'Rhode Island': 'RI',
    'South Carolina': 'SC',
    'South Dakota': 'SD',
    'Tennessee': 'TN',
    'Texas': 'TX',
    'Utah': 'UT',
    'Vermont': 'VT',
    'Virgin Islands': 'VI',
    'Virginia': 'VA',
    'Washington': 'WA',
    'West Virginia': 'WV',
    'Wisconsin': 'WI',
    'Wyoming': 'WY'
}
"""
Code Reference
Roger Allen (Mar 31 2021).Github Gist. 
Available at: https://gist.github.com/rogerallen/1583593 (Accessed 8/4/21).
"""

# %%
#We need to invert this dictionary
state_dict = dict(map(reversed, us_state_abbrev.items()))
state_dict
# Out:
# {'AL': 'Alabama',
#  'AK': 'Alaska',
#  'AS': 'American Samoa',
#  'AZ': 'Arizona',
#  'AR': 'Arkansas',
#  'CA': 'California',
#  'CO': 'Colorado',
#  'CT': 'Connecticut',
#  'DE': 'Delaware',
#  'DC': 'District of Columbia',
#  'FL': 'Florida',
#  'GA': 'Georgia',
#  'GU': 'Guam',
#  'HI': 'Hawaii',
#  'ID': 'Idaho',
#  'IL': 'Illinois',
#  'IN': 'Indiana',
#  'IA': 'Iowa',
#  'KS': 'Kansas',
#  'KY': 'Kentucky',
#  'LA': 'Louisiana',
#  'ME': 'Maine',
#  'MD': 'Maryland',
#  'MA': 'Massachusetts',
#  'MI': 'Michigan',
#  'MN': 'Minnesota',
#  'MS': 'Mississippi',
#  'MO': 'Missouri',
#  'MT': 'Montana',
#  'NE': 'Nebraska',
#  'NV': 'Nevada',
#  'NH': 'New Hampshire',
#  'NJ': 'New Jersey',
#  'NM': 'New Mexico',
#  'NY': 'New York',
#  'NC': 'North Carolina',
#  'ND': 'North Dakota',
#  'MP': 'Northern Mariana Islands',
#  'OH': 'Ohio',
#  'OK': 'Oklahoma',
#  'OR': 'Oregon',
#  'PA': 'Pennsylvania',
#  'PR': 'Puerto Rico',
#  'RI': 'Rhode Island',
#  'SC': 'South Carolina',
#  'SD': 'South Dakota',
#  'TN': 'Tennessee',
#  'TX': 'Texas',
#  'UT': 'Utah',
#  'VT': 'Vermont',
#  'VI': 'Virgin Islands',
#  'VA': 'Virginia',
#  'WA': 'Washington',
#  'WV': 'West Virginia',
#  'WI': 'Wisconsin',
#  'WY': 'Wyoming'}

# %%
land_area_df2['State'] = land_area_df2['State Code'].map(state_dict)
land_area_df2
# Out:
#      County/City  Land Area State Code    State
# 0        Autauga     594.44         AL  Alabama
# 1        Baldwin    1589.78         AL  Alabama
# 2        Barbour     884.88         AL  Alabama
# 3           Bibb     622.58         AL  Alabama
# 4         Blount     644.78         AL  Alabama
# ...          ...        ...        ...      ...
# 3140  Sweetwater   10426.65         WY  Wyoming
# 3141       Teton    3995.38         WY  Wyoming
# 3142       Uinta    2081.26         WY  Wyoming
# 3143    Washakie    2238.55         WY  Wyoming
# 3144      Weston    2398.09         WY  Wyoming
#
# [3145 rows x 4 columns]

# %%
land_area_df2 = land_area_df2.drop(['State Code'], axis = 1)
land_area_df2 = land_area_df2[['County/City', 'State', 'Land Area']]
land_area_df2
# Out:
#      County/City    State  Land Area
# 0        Autauga  Alabama     594.44
# 1        Baldwin  Alabama    1589.78
# 2        Barbour  Alabama     884.88
# 3           Bibb  Alabama     622.58
# 4         Blount  Alabama     644.78
# ...          ...      ...        ...
# 3140  Sweetwater  Wyoming   10426.65
# 3141       Teton  Wyoming    3995.38
# 3142       Uinta  Wyoming    2081.26
# 3143    Washakie  Wyoming    2238.55
# 3144      Weston  Wyoming    2398.09
#
# [3145 rows x 3 columns]

# %% [markdown]
# ### Calculating Pop Density for county city

# %%
est_pop_df2
# Out:
#             County/City    State  Population
# 1        Autauga County  Alabama       55533
# 2        Baldwin County  Alabama      217855
# 3        Barbour County  Alabama       24872
# 4           Bibb County  Alabama       22367
# 5         Blount County  Alabama       57771
# ...                 ...      ...         ...
# 3138  Sweetwater County  Wyoming       42858
# 3139       Teton County  Wyoming       23269
# 3140       Uinta County  Wyoming       20292
# 3141    Washakie County  Wyoming        7877
# 3142      Weston County  Wyoming        6924
#
# [3142 rows x 3 columns]

# %%
est_pop_df2
# Out:
#             County/City    State  Population
# 1        Autauga County  Alabama       55533
# 2        Baldwin County  Alabama      217855
# 3        Barbour County  Alabama       24872
# 4           Bibb County  Alabama       22367
# 5         Blount County  Alabama       57771
# ...                 ...      ...         ...
# 3138  Sweetwater County  Wyoming       42858
# 3139       Teton County  Wyoming       23269
# 3140       Uinta County  Wyoming       20292
# 3141    Washakie County  Wyoming        7877
# 3142      Weston County  Wyoming        6924
#
# [3142 rows x 3 columns]

# %%
land_area_df2
# Out:
#      County/City    State  Land Area
# 0        Autauga  Alabama     594.44
# 1        Baldwin  Alabama    1589.78
# 2        Barbour  Alabama     884.88
# 3           Bibb  Alabama     622.58
# 4         Blount  Alabama     644.78
# ...          ...      ...        ...
# 3140  Sweetwater  Wyoming   10426.65
# 3141       Teton  Wyoming    3995.38
# 3142       Uinta  Wyoming    2081.26
# 3143    Washakie  Wyoming    2238.55
# 3144      Weston  Wyoming    2398.09
#
# [3145 rows x 3 columns]

# %%
est_pop_df2
est_pop_df2 = est_pop_df2.rename(columns = {"County/City": "temp_name"})

# %%
new_df = est_pop_df2['temp_name'].str.split(' ', n = 0, expand = True)
est_pop_df2["County/City"] = new_df[0] 
est_pop_df2
# Out:
#               temp_name    State  Population County/City
# 1        Autauga County  Alabama       55533     Autauga
# 2        Baldwin County  Alabama      217855     Baldwin
# 3        Barbour County  Alabama       24872     Barbour
# 4           Bibb County  Alabama       22367        Bibb
# 5         Blount County  Alabama       57771      Blount
# ...                 ...      ...         ...         ...
# 3138  Sweetwater County  Wyoming       42858  Sweetwater
# 3139       Teton County  Wyoming       23269       Teton
# 3140       Uinta County  Wyoming       20292       Uinta
# 3141    Washakie County  Wyoming        7877    Washakie
# 3142      Weston County  Wyoming        6924      Weston
#
# [3142 rows x 4 columns]

# %%
msa_pop_den_df = land_area_df2.merge(est_pop_df2, on=['County/City', 'State'], how='left')
msa_pop_den_df = msa_pop_den_df.drop('County/City', axis=1)
msa_pop_den_df = msa_pop_den_df.rename(columns = {"temp_name": "County/City"})
msa_pop_den_df
# Out:
#         State  Land Area        County/City  Population
# 0     Alabama     594.44     Autauga County     55533.0
# 1     Alabama    1589.78     Baldwin County    217855.0
# 2     Alabama     884.88     Barbour County     24872.0
# 3     Alabama     622.58        Bibb County     22367.0
# 4     Alabama     644.78      Blount County     57771.0
# ...       ...        ...                ...         ...
# 3154  Wyoming   10426.65  Sweetwater County     42858.0
# 3155  Wyoming    3995.38       Teton County     23269.0
# 3156  Wyoming    2081.26       Uinta County     20292.0
# 3157  Wyoming    2238.55    Washakie County      7877.0
# 3158  Wyoming    2398.09      Weston County      6924.0
#
# [3159 rows x 4 columns]

# %%
msa_pop_den_df = msa_pop_den_df[['County/City', 'State', 'Land Area', 'Population']]
msa_pop_den_df
# Out:
#             County/City    State  Land Area  Population
# 0        Autauga County  Alabama     594.44     55533.0
# 1        Baldwin County  Alabama    1589.78    217855.0
# 2        Barbour County  Alabama     884.88     24872.0
# 3           Bibb County  Alabama     622.58     22367.0
# 4         Blount County  Alabama     644.78     57771.0
# ...                 ...      ...        ...         ...
# 3154  Sweetwater County  Wyoming   10426.65     42858.0
# 3155       Teton County  Wyoming    3995.38     23269.0
# 3156       Uinta County  Wyoming    2081.26     20292.0
# 3157    Washakie County  Wyoming    2238.55      7877.0
# 3158      Weston County  Wyoming    2398.09      6924.0
#
# [3159 rows x 4 columns]

# %%
msa_pop_den_df['Population Density'] = msa_pop_den_df['Population'] / msa_pop_den_df['Land Area']
msa_pop_den_df
# Out:
# <ipython-input-49-b45f5168fa75>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   msa_pop_den_df['Population Density'] = msa_pop_den_df['Population'] / msa_pop_den_df['Land Area']
#             County/City    State  Land Area  Population  Population Density
# 0        Autauga County  Alabama     594.44     55533.0           93.420698
# 1        Baldwin County  Alabama    1589.78    217855.0          137.034684
# 2        Barbour County  Alabama     884.88     24872.0           28.107766
# 3           Bibb County  Alabama     622.58     22367.0           35.926307
# 4         Blount County  Alabama     644.78     57771.0           89.598002
# ...                 ...      ...        ...         ...                 ...
# 3154  Sweetwater County  Wyoming   10426.65     42858.0            4.110429
# 3155       Teton County  Wyoming    3995.38     23269.0            5.823977
# 3156       Uinta County  Wyoming    2081.26     20292.0            9.749863
# 3157    Washakie County  Wyoming    2238.55      7877.0            3.518796
# 3158      Weston County  Wyoming    2398.09      6924.0            2.887298
#
# [3159 rows x 5 columns]

# %%
msa_pop_den_df.isnull().sum()
# Out:
# County/City           205
# State                   0
# Land Area               0
# Population            205
# Population Density    205
# dtype: int64

# %%
msa_pop_den_df = msa_pop_den_df.dropna()
msa_pop_den_df
# Out:
#             County/City    State  Land Area  Population  Population Density
# 0        Autauga County  Alabama     594.44     55533.0           93.420698
# 1        Baldwin County  Alabama    1589.78    217855.0          137.034684
# 2        Barbour County  Alabama     884.88     24872.0           28.107766
# 3           Bibb County  Alabama     622.58     22367.0           35.926307
# 4         Blount County  Alabama     644.78     57771.0           89.598002
# ...                 ...      ...        ...         ...                 ...
# 3154  Sweetwater County  Wyoming   10426.65     42858.0            4.110429
# 3155       Teton County  Wyoming    3995.38     23269.0            5.823977
# 3156       Uinta County  Wyoming    2081.26     20292.0            9.749863
# 3157    Washakie County  Wyoming    2238.55      7877.0            3.518796
# 3158      Weston County  Wyoming    2398.09      6924.0            2.887298
#
# [2954 rows x 5 columns]

# %%
msa_pop_den_df.describe()
# Out:
#            Land Area    Population  Population Density
# count    2954.000000  2.954000e+03         2954.000000
# mean     1034.963561  9.641063e+04          301.302455
# std      3171.129583  2.711971e+05         3600.221482
# min         2.500000  8.600000e+01            0.036830
# 25%       430.410000  1.100025e+04           17.041044
# 50%       609.195000  2.553400e+04           44.809639
# 75%       911.375000  6.673400e+04          114.923778
# max    145504.790000  5.171960e+06       184048.557692

# %%
msa_pop_den_df.sort_values('Population Density', ascending=False).head(20)
# Out:
#                County/City          State  Land Area  Population  \
# 2934        Fairfax County       Virginia       6.24   1148463.0
# 1855          Kings County       New York      70.82   2578074.0
# 1834          Bronx County       New York      42.10   1432087.0
# 1872         Queens County       New York     108.53   2274605.0
# 1786         Hudson County     New Jersey      46.19    671931.0
# 1230        Suffolk County  Massachusetts      58.15    803147.0
# 2298   Philadelphia County   Pennsylvania     134.10   1583592.0
# 2924        Bedford County       Virginia       6.88     78882.0
# 2923       Alexandria city       Virginia      15.03    159069.0
# 2830      Arlington County       Virginia      25.97    236025.0
# 1874       Richmond County       New York      58.37    476260.0
# 2937       Franklin County       Virginia       8.21     56191.0
# 1784          Essex County     New Jersey     126.21    798570.0
# 609            Cook County       Illinois     945.33   5171960.0
# 1797          Union County     New Jersey     102.86    556402.0
# 1861         Nassau County       New York     284.72   1357534.0
# 260          Denver County       Colorado     153.00    716265.0
# 2927  Charlottesville city       Virginia      10.24     47506.0
# 2951          Norfolk city       Virginia      54.12    243585.0
# 2946         Manassas city       Virginia       9.88     41046.0
#
#       Population Density
# 2934       184048.557692
# 1855        36403.191189
# 1834        34016.318290
# 1872        20958.306459
# 1786        14547.109764
# 1230        13811.642304
# 2298        11809.038031
# 2924        11465.406977
# 2923        10583.433134
# 2830         9088.371198
# 1874         8159.328422
# 2937         6844.214373
# 1784         6327.311623
# 609          5471.063015
# 1797         5409.313630
# 1861         4767.961506
# 260          4681.470588
# 2927         4639.257812
# 2951         4500.831486
# 2946         4154.453441

# %% [markdown]
# # Saving the Dataframe

# %%
state_pop_den_df.to_csv(PROCESSED_STATE_POP_DEN_DATASET)

# %%
msa_pop_den_df.to_csv(PROCESSED_MSA_POP_DEN_DATASET, index=False)
